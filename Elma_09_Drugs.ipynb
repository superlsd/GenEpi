# %% [markdown]
# This notebook is used to calculate the relationships between diseases and drugs from a molecular point of view, considering
# individual diseases and agglomereted trajectories

# %%
import pandas as pd
import pickle as pk
import networkx as nx
import collections
import random as rd
import itertools as it
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

import xml.etree.ElementTree as ET
import time

dB_file = 'input/DrugBank_FullDatabase.xml'
organism = 'Humans'
xtree = ET.parse(dB_file)
xroot = xtree.getroot()


#This method is described here:
#https://github.com/dhimmel/drugbank/blob/gh-pages/parse.ipynb

# %%
def fisher_test(lstA, lstB,background):
    import scipy.stats as stats
    """
    Accepts to lists
    M is the population size (previously N)
    n is the number of successes in the population
    N is the sample size (previously n)
    x is still the number of drawn “successes”
    """
    setA= set(lstA)
    setB= set(lstB)
    M= background
    n= len(setA)
    N= len(setB)
    x= len(setA.intersection(setB))

    return str(stats.hypergeom.sf(x-1, M, n, N))

import scipy  
from scipy import stats

#Here we define the adjustment
from statsmodels.sandbox.stats.multicomp import multipletests
def fdr_adjustment(list_of_pvals,alpha):    
    return multipletests(list_of_pvals,alpha=alpha,method='fdr_bh')[1] #the benjamin hochberg method is used

# %%
def collapse_list_values(row):
    for key, value in row.items():
        if isinstance(value, list):
            row[key] = '|'.join(value)
    return row

# %%
#Let's import the ICD-name dictionary
icd_naming_df = pd.read_csv("output/disease_name.tsv",sep="\t")

# %%
#Let's extract the drug information
ns = '{http://www.drugbank.ca}'
inchikey_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChIKey']/{ns}value"
inchi_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChI']/{ns}value"

rows = list()
for i, drug in enumerate(xroot):
    row = collections.OrderedDict()
    assert drug.tag == ns + 'drug'
    row['type'] = drug.get('type')
    row['drugbank_id'] = drug.findtext(ns + "drugbank-id[@primary='true']")
    row['name'] = drug.findtext(ns + "name")
    row['description'] = drug.findtext(ns + "description")
    row['groups'] = [group.text for group in
        drug.findall("{ns}groups/{ns}group".format(ns = ns))]
    row['atc_codes'] = [code.get('code') for code in
        drug.findall("{ns}atc-codes/{ns}atc-code".format(ns = ns))]
    row['categories'] = [x.findtext(ns + 'category') for x in
        drug.findall("{ns}categories/{ns}category".format(ns = ns))]
    row['inchi'] = drug.findtext(inchi_template.format(ns = ns))
    row['inchikey'] = drug.findtext(inchikey_template.format(ns = ns))
    row['indication'] = drug.findtext(ns + "indication")
    row['mechanism-of-action'] = drug.findtext(ns + "mechanism-of-action")

    
    
    # Add drug aliases
    aliases = {
        elem.text for elem in 
        drug.findall("{ns}international-brands/{ns}international-brand".format(ns = ns)) +
        drug.findall("{ns}synonyms/{ns}synonym[@language='English']".format(ns = ns)) +
        drug.findall("{ns}international-brands/{ns}international-brand".format(ns = ns)) +
        drug.findall("{ns}products/{ns}product/{ns}name".format(ns = ns))

    }
    aliases.add(row['name'])
    row['aliases'] = sorted(aliases)

    rows.append(row)

# %%
columns = ['drugbank_id', 'name', 'type', 'indication','mechanism-of-action','groups', 'atc_codes', 'categories', 'inchikey', 'inchi', 'description']
drugbank_df = pd.DataFrame.from_dict(rows)[columns]
drugbank_df.head()
# Out:
#   drugbank_id                 name     type  \
# 0     DB00001            Lepirudin  biotech
# 1     DB00002            Cetuximab  biotech
# 2     DB00003         Dornase alfa  biotech
# 3     DB00004  Denileukin diftitox  biotech
# 4     DB00005           Etanercept  biotech
#
#                                           indication  \
# 0  For the treatment of heparin-induced thrombocy...
# 1  Cetuximab, used in combination with irinotecan...
# 2  Used as adjunct therapy in the treatment of cy...
# 3         For treatment of cutaneous T-cell lymphoma
# 4  Etanercept is indicated for the treatment of m...
#
#                                  mechanism-of-action  \
# 0  Lepirudin forms a stable non-covalent complex ...
# 1  Cetuximab binds to the epidermal growth factor...
# 2  Dornase alfa is a biosynthetic form of human D...
# 3  Denileukin diftitox binds to the high-affinity...
# 4  There are two distinct receptors for TNF (TNFR...
#
#                         groups  atc_codes  \
# 0                   [approved]  [B01AE02]
# 1                   [approved]  [L01XC06]
# 2                   [approved]  [R05CB13]
# 3  [approved, investigational]  [L01XX29]
# 4  [approved, investigational]  [L04AB01]
#
#                                           categories inchikey inchi  \
# 0  [Amino Acids, Peptides, and Proteins, Anticoag...     None  None
# 1  [Amino Acids, Peptides, and Proteins, Antibodi...     None  None
# 2  [Amino Acids, Peptides, and Proteins, Cough an...     None  None
# 3  [ADP Ribose Transferases, Amino Acids, Peptide...     None  None
# 4  [Amino Acids, Peptides, and Proteins, Analgesi...     None  None
#
#                                          description
# 0  Lepirudin is identical to natural hirudin exce...
# 1  Cetuximab is an epidermal growth factor recept...
# 2  Dornase alfa is a biosynthetic form of human d...
# 3  A recombinant DNA-derived cytotoxic protein co...
# 4  Dimeric fusion protein consisting of the extra...

# %%
#Let's focus only on the approved drugs
drugbank_approved_df = drugbank_df[
    drugbank_df.groups.map(lambda x: 'approved' in x) ]
drugbank_approved_df.head()
# Out:
#   drugbank_id                 name     type  \
# 0     DB00001            Lepirudin  biotech
# 1     DB00002            Cetuximab  biotech
# 2     DB00003         Dornase alfa  biotech
# 3     DB00004  Denileukin diftitox  biotech
# 4     DB00005           Etanercept  biotech
#
#                                           indication  \
# 0  For the treatment of heparin-induced thrombocy...
# 1  Cetuximab, used in combination with irinotecan...
# 2  Used as adjunct therapy in the treatment of cy...
# 3         For treatment of cutaneous T-cell lymphoma
# 4  Etanercept is indicated for the treatment of m...
#
#                                  mechanism-of-action  \
# 0  Lepirudin forms a stable non-covalent complex ...
# 1  Cetuximab binds to the epidermal growth factor...
# 2  Dornase alfa is a biosynthetic form of human D...
# 3  Denileukin diftitox binds to the high-affinity...
# 4  There are two distinct receptors for TNF (TNFR...
#
#                         groups  atc_codes  \
# 0                   [approved]  [B01AE02]
# 1                   [approved]  [L01XC06]
# 2                   [approved]  [R05CB13]
# 3  [approved, investigational]  [L01XX29]
# 4  [approved, investigational]  [L04AB01]
#
#                                           categories inchikey inchi  \
# 0  [Amino Acids, Peptides, and Proteins, Anticoag...     None  None
# 1  [Amino Acids, Peptides, and Proteins, Antibodi...     None  None
# 2  [Amino Acids, Peptides, and Proteins, Cough an...     None  None
# 3  [ADP Ribose Transferases, Amino Acids, Peptide...     None  None
# 4  [Amino Acids, Peptides, and Proteins, Analgesi...     None  None
#
#                                          description
# 0  Lepirudin is identical to natural hirudin exce...
# 1  Cetuximab is an epidermal growth factor recept...
# 2  Dornase alfa is a biosynthetic form of human d...
# 3  A recombinant DNA-derived cytotoxic protein co...
# 4  Dimeric fusion protein consisting of the extra...

# %%
#Let's extract the drug indications of approved drugs for ICD-10 terms
disease_approveddrugs_dict = {}
for i,v in icd_naming_df.iterrows():
    icd_code = v['ICD']
    icd_name = v['Disease Name'].lower()
    drug_list = []
    for i,v in drugbank_approved_df.iterrows():
        indication = v['indication'].lower()
        drug_name = v['name']
        if icd_name in indication:
            drug_list.append(drug_name)
    if len(drug_list)>0:
        disease_approveddrugs_dict[icd_code] = drug_list

print(len(disease_approveddrugs_dict))
# Out:
# 260

# %%
#This is the total list of drugs that will be used as background of the Fisher's exact test for future comparisons
tot_drug_list = []

for drug_list in list(disease_approveddrugs_dict.values()):
    for drg in drug_list:
        if drg not in tot_drug_list:
            tot_drug_list.append(drg)
print(len(tot_drug_list))
# Out:
# 1174

# %%
#Let's import the trajectories
with open('output/male_trajectories_dict_filtered_unique.pickle', 'rb') as handle:
    male_trajectories_dict_filtered_unique = pk.load(handle)
    
with open('output/female_trajectories_dict_filtered_unique.pickle', 'rb') as handle:
    female_trajectories_dict_filtered_unique = pk.load(handle)

# %%
#Let's import the epidemiological networks

G_elma_icd_female_df = pd.read_csv('output/G_elma_icd_female_df.tsv', sep="\t",index_col=0)
G_elma_icd_male_df = pd.read_csv('output/G_elma_icd_male_df.tsv', sep="\t",index_col=0)

#Let's import the genetic network
G_gene_icd_disp_significant_post_df = pd.read_csv("output/G_gene_icd_disp_significant_post_df.tsv", sep="\t",index_col=0)
G_gene_icd_disp_significant_post = nx.from_pandas_edgelist(G_gene_icd_disp_significant_post_df, 'Dis A', 'Dis B')

# %%
#Let's filter by keeping only those trajectories that had at least one associated drug
male_trajectories_dict_filtered_unique_with_drugs_dict = {}
for trj,dislist in male_trajectories_dict_filtered_unique.items():
    new_dislist = set(dislist) & set(disease_approveddrugs_dict.keys())
    if len(new_dislist)>1:
        male_trajectories_dict_filtered_unique_with_drugs_dict[trj] = new_dislist
        
print(len(male_trajectories_dict_filtered_unique_with_drugs_dict))
# Out:
# 110

# %%
#Let's check the number of unique trajectories that share at least one drugs across all pairwise comparisons

male_trj_with_atleast_one_common_drug_across_all_pairwise = []
for trj,disset in male_trajectories_dict_filtered_unique_with_drugs_dict.items():
    pairwise_comb = list(it.combinations(list(disset),2))
    drug_intersecton_list = []
    for dis1,dis2 in pairwise_comb:
        drug_intersection = set(disease_approveddrugs_dict[dis1]) & set(disease_approveddrugs_dict[dis2])
        if len(drug_intersection)>0:
            drug_intersecton_list.append((dis1,dis2))
    if len(drug_intersecton_list)==len(pairwise_comb):
        male_trj_with_atleast_one_common_drug_across_all_pairwise.append(trj)
        

print(len(male_trj_with_atleast_one_common_drug_across_all_pairwise))
# Out:
# 20

# %%
#Let's check the number of unique trajectories that have at least one statistically significant drug overlap across
#all disease pairwise

male_trj_with_atleast_one_significant_shared_drug_across_all_pairwise = []
for trj,disset in male_trajectories_dict_filtered_unique_with_drugs_dict.items():
    pairwise_comb = list(it.combinations(list(disset),2))
    drug_intersection_pval_dict = {}
    drug_intersection_fdr_dict = {}
    drug_intersection_sigfdr_dict = {}
    
    for dis1,dis2 in pairwise_comb:
        drug_intersection_pval = float(fisher_test(disease_approveddrugs_dict[dis1],disease_approveddrugs_dict[dis2],len(tot_drug_list)))
        drug_intersection_pval_dict[(dis1,dis2)] = drug_intersection_pval
        
    drug_intersection_adj_pval_list = fdr_adjustment(list(drug_intersection_pval_dict.values()),0.05)
    pair_list=list(drug_intersection_pval_dict.keys())
    for i in range(len(drug_intersection_adj_pval_list)):
        drug_intersection_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

    for dis_pair,fdr in drug_intersection_fdr_dict.items():
        if fdr<0.05:
            drug_intersection_sigfdr_dict[dis_pair] = fdr

    if len(drug_intersection_fdr_dict)>1:
        male_trj_with_atleast_one_significant_shared_drug_across_all_pairwise.append(trj)

print(len(male_trj_with_atleast_one_significant_shared_drug_across_all_pairwise))
# Out:
# 50

# %%
set.intersection(*map(set,[disease_approveddrugs_dict[dis] for dis in male_trajectories_dict_filtered_unique_with_drugs_dict['151']]))
# Out:
# {'Omeprazole'}

# %%
#Let's do the same for females
female_trajectories_dict_filtered_unique_with_drugs_dict = {}
for trj,dislist in female_trajectories_dict_filtered_unique.items():
    new_dislist = set(dislist) & set(disease_approveddrugs_dict.keys())
    if len(new_dislist)>1:
        female_trajectories_dict_filtered_unique_with_drugs_dict[trj] = new_dislist
        
print(len(female_trajectories_dict_filtered_unique_with_drugs_dict))
# Out:
# 119

# %%
#Let's check the number of unique trajectories that share at least one drugs across all pairwise comparisons

female_trj_with_atleast_one_common_drug_across_all_pairwise = []
for trj,disset in female_trajectories_dict_filtered_unique_with_drugs_dict.items():
    pairwise_comb = list(it.combinations(list(disset),2))
    drug_intersecton_list = []
    for dis1,dis2 in pairwise_comb:
        drug_intersection = set(disease_approveddrugs_dict[dis1]) & set(disease_approveddrugs_dict[dis2])
        if len(drug_intersection)>0:
            drug_intersecton_list.append((dis1,dis2))
    if len(drug_intersecton_list)==len(pairwise_comb):
        female_trj_with_atleast_one_common_drug_across_all_pairwise.append(trj)
        

print(len(female_trj_with_atleast_one_common_drug_across_all_pairwise))
# Out:
# 21

# %%
#Let's check the number of unique trajectories that have at least one statistically significant drug overlap across
#all disease pairwise

female_trj_with_atleast_one_significant_shared_drug_across_all_pairwise = []
for trj,disset in female_trajectories_dict_filtered_unique_with_drugs_dict.items():
    pairwise_comb = list(it.combinations(list(disset),2))
    drug_intersection_pval_dict = {}
    drug_intersection_fdr_dict = {}
    drug_intersection_sigfdr_dict = {}
    
    for dis1,dis2 in pairwise_comb:
        drug_intersection_pval = float(fisher_test(disease_approveddrugs_dict[dis1],disease_approveddrugs_dict[dis2],len(tot_drug_list)))
        drug_intersection_pval_dict[(dis1,dis2)] = drug_intersection_pval
        
    drug_intersection_adj_pval_list = fdr_adjustment(list(drug_intersection_pval_dict.values()),0.05)
    pair_list=list(drug_intersection_pval_dict.keys())
    for i in range(len(drug_intersection_adj_pval_list)):
        drug_intersection_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

    for dis_pair,fdr in drug_intersection_fdr_dict.items():
        if fdr<0.05:
            drug_intersection_sigfdr_dict[dis_pair] = fdr

    if len(drug_intersection_fdr_dict)>1:
        female_trj_with_atleast_one_significant_shared_drug_across_all_pairwise.append(trj)

print(len(female_trj_with_atleast_one_significant_shared_drug_across_all_pairwise))
# Out:
# 46

# %%
male_trajectories_dict_filtered_unique_with_drugs_df = pd.DataFrame()

trj_list = []
dis_list = []
drug_list = []

for trj,disset in male_trajectories_dict_filtered_unique_with_drugs_dict.items():
    trj_list.append(trj)
    dis_list.append(str(disset))
    dg_list = []
    for dis in disset:
        dg_list.extend(disease_approveddrugs_dict[dis])
        
    drug_list.append(str(dict(Counter(dg_list))))

male_trajectories_dict_filtered_unique_with_drugs_df["Trajectory"] = trj_list
male_trajectories_dict_filtered_unique_with_drugs_df["Disease list"] = dis_list
male_trajectories_dict_filtered_unique_with_drugs_df["Drug Indications"] = drug_list

male_trajectories_dict_filtered_unique_with_drugs_df.head()

male_trajectories_dict_filtered_unique_with_drugs_df.to_csv("output/SuppTab6_male_trj_drug_indications.csv")

# %%
female_trajectories_dict_filtered_unique_with_drugs_df = pd.DataFrame()

trj_list = []
dis_list = []
drug_list = []

for trj,disset in female_trajectories_dict_filtered_unique_with_drugs_dict.items():
    trj_list.append(trj)
    dis_list.append(str(disset))
    dg_list = []
    for dis in disset:
        dg_list.extend(disease_approveddrugs_dict[dis])
        
    drug_list.append(str(dict(Counter(dg_list))))

female_trajectories_dict_filtered_unique_with_drugs_df["Trajectory"] = trj_list
female_trajectories_dict_filtered_unique_with_drugs_df["Disease list"] = dis_list
female_trajectories_dict_filtered_unique_with_drugs_df["Drug Indications"] = drug_list

female_trajectories_dict_filtered_unique_with_drugs_df.head()

female_trajectories_dict_filtered_unique_with_drugs_df.to_csv("output/SuppTab6_female_trj_drug_indications.csv")

# %%
#Let's import the genetic enad the epidemiolgoical networks
G_elma_icd_female_df = pd.read_csv('output/G_elma_icd_female_df.tsv', sep="\t",index_col=0)
G_elma_icd_female_nx = nx.from_pandas_edgelist(G_elma_icd_female_df, 'Dis A', 'Dis B')
G_elma_icd_male_df = pd.read_csv('output/G_elma_icd_male_df.tsv', sep="\t",index_col=0)
G_elma_icd_male_nx = nx.from_pandas_edgelist(G_elma_icd_male_df, 'Dis A', 'Dis B')

#Let's import the genetic network
G_gene_icd_disp_significant_post_df = pd.read_csv("output/G_gene_icd_disp_significant_post_df.tsv", sep="\t",index_col=0)
G_gene_icd_disp_significant_post = nx.from_pandas_edgelist(G_gene_icd_disp_significant_post_df, 'Dis A', 'Dis B')

# %%
#Let's compare the number of shared drugs across all pairwise diseases vs disease pairs that are in at least one epidemiological network
#vs those pairs that are present in the genetic network and those that are in all pairs

tot_disease_with_drugs_pairs_list = list(it.combinations(list(disease_approveddrugs_dict.keys()),2))
epidemiological_disease_pairs_with_drugs = []
genetic_disease_pairs_with_drugs = []

for dispair in tot_disease_with_drugs_pairs_list:
    if (dispair[0],dispair[1]) in G_elma_icd_female_nx.edges():
        epidemiological_disease_pairs_with_drugs.append(dispair)
    elif (dispair[1],dispair[0]) in G_elma_icd_female_nx.edges():
        epidemiological_disease_pairs_with_drugs.append(dispair)
    elif (dispair[0],dispair[1]) in G_elma_icd_male_nx.edges():
        if dispair not in epidemiological_disease_pairs_with_drugs:
            epidemiological_disease_pairs_with_drugs.append(dispair)
    elif (dispair[1],dispair[0]) in G_elma_icd_male_nx.edges():
        if dispair not in epidemiological_disease_pairs_with_drugs:
            epidemiological_disease_pairs_with_drugs.append(dispair)

for dispair in tot_disease_with_drugs_pairs_list:
    if (dispair[0],dispair[1]) in G_gene_icd_disp_significant_post.edges():
        genetic_disease_pairs_with_drugs.append(dispair)
    elif (dispair[1],dispair[0]) in G_gene_icd_disp_significant_post.edges():
        genetic_disease_pairs_with_drugs.append(dispair)

genetic_and_epidemiological_disease_pairs_with_drugs = list(set(epidemiological_disease_pairs_with_drugs)&set(genetic_disease_pairs_with_drugs))

print(len(tot_disease_with_drugs_pairs_list))
print(len(epidemiological_disease_pairs_with_drugs))
print(len(genetic_disease_pairs_with_drugs))
print(len(genetic_and_epidemiological_disease_pairs_with_drugs))
# Out:
# 33670
# 226
# 2049
# 34

# %%
# Create the density plot
plt.figure(figsize=(10, 6))
sns.kdeplot([len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) for disA,disB in tot_disease_with_drugs_pairs_list], 
            label="All pairwise", fill=True)
sns.kdeplot([len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) for disA,disB in epidemiological_disease_pairs_with_drugs], 
            label="Epidemiological Network", fill=True)
sns.kdeplot([len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) for disA,disB in genetic_disease_pairs_with_drugs],
            label="Genetic Network", fill=True)
sns.kdeplot([len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) for disA,disB in genetic_and_epidemiological_disease_pairs_with_drugs],
            label="Epidemiological & Genetic Network", fill=True)

# Customize the plot
plt.xlabel("Number of shared drugs")
plt.ylabel("Density")
#plt.xscale("log")
plt.title("Shared drugs across disease pairs")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Compute the number of shared drugs for each category
data = [
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in tot_disease_with_drugs_pairs_list],
    
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in epidemiological_disease_pairs_with_drugs],
    
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in genetic_disease_pairs_with_drugs],
    
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in genetic_and_epidemiological_disease_pairs_with_drugs]
]

# Labels for each violin plot
labels = [
    "All pairwise",
    "Epidemiological Network",
    "Genetic Network",
    "Epidemiological & Genetic Network"
]

# Create the violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, scale="width")

# Customize the plot
plt.xticks(ticks=range(len(labels)), labels=labels, rotation=20)  # Set x-axis labels
plt.xlabel("Disease Pair Category")
plt.ylabel("Number of Shared Drugs")
#plt.yscale("log")  # Keep logarithmic scale
plt.title("Shared Drugs Across Disease Pairs")
plt.grid(True)

plt.savefig('Figures/Fig5C_shareddrugs_disease_pairs.pdf',format='pdf',dpi=300, bbox_inches = "tight")
# Show the plot
plt.show()
# Out:
# C:\Users\salvo\AppData\Local\Temp\ipykernel_12800\218218697.py:26: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(data=data, scale="width")

# %%
#Let's create a table with the disease pairs and their share drugs
disease_drugs_shared_df = pd.DataFrame()

disA_list = []
disB_list = []
epidemiological_status_list = []
genetic_status_list = []
shared_drug_list = []


for dispair in tot_disease_with_drugs_pairs_list:
    disA = dispair[0]
    disB = dispair[1]
    disA_list.append(disA)
    disB_list.append(disB)
    if (disA,disB) in epidemiological_disease_pairs_with_drugs or (disB,disA) in epidemiological_disease_pairs_with_drugs:
        epidemiological_status_list.append(True)
    else:
        epidemiological_status_list.append(False)
    if (disA,disB) in genetic_disease_pairs_with_drugs or (disB,disA) in genetic_disease_pairs_with_drugs:
        genetic_status_list.append(True)
    else:
        genetic_status_list.append(False)
    shared_drugs_set = set(disease_approveddrugs_dict[disA])&set(disease_approveddrugs_dict[disB])
    shared_drug_list.append(str(shared_drugs_set))

disease_drugs_shared_df["Disease A"] = disA_list
disease_drugs_shared_df["Disease B"] = disB_list
disease_drugs_shared_df["Epidemiological network"] = epidemiological_status_list
disease_drugs_shared_df["Genetic network"] = genetic_status_list
disease_drugs_shared_df["Shared drugs"] = shared_drug_list

disease_drugs_shared_df.head()
# Out:
#   Disease A Disease B  Epidemiological network  Genetic network Shared drugs
# 0       N19       N80                    False            False        set()
# 1       N19       A20                    False            False        set()
# 2       N19       L64                    False             True        set()
# 3       N19       G30                    False            False        set()
# 4       N19       L80                    False            False        set()

# %%
disease_drugs_shared_df.to_csv("output/Supp_Tab4_disease_drugs_shared_df.csv")

# %%
# Define data categories
categories = [
    "All pairwise",
    "Epidemiological Network",
    "Genetic Network",
    "Epidemiological & Genetic Network"
]

# Generate the data (Replace with actual data)
data = [
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in tot_disease_with_drugs_pairs_list],
    
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in epidemiological_disease_pairs_with_drugs],
    
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in genetic_disease_pairs_with_drugs],
    
    [len(set(disease_approveddrugs_dict[disA]) & set(disease_approveddrugs_dict[disB])) 
     for disA, disB in genetic_and_epidemiological_disease_pairs_with_drugs]
]

# Convert data into a DataFrame
df = pd.DataFrame({
    "Category": np.repeat(categories, [len(d) for d in data]), 
    "Shared Drugs": np.concatenate(data)
})

# Set seaborn style
sns.set_style("whitegrid")

# Create figure
plt.figure(figsize=(12, 6))

# Define colors
palette = ["#6A5ACD", "#FF8C00", "#3CB371", "#DC143C"]

# Plot violin with bandwidth adjustment and split to optimize
sns.violinplot(data=df, x="Category", y="Shared Drugs", 
               palette=palette, scale="width", bw_adjust=0.5, 
               inner="quartile", cut=0)

# Overlay fast scatterplot instead of swarmplot
sns.stripplot(data=df, x="Category", y="Shared Drugs", 
              color="black", alpha=0.3, size=1, jitter=True)

# Customize aesthetics
plt.xticks(rotation=20, fontsize=12)
plt.xlabel("Disease Pair Category", fontsize=14)
plt.ylabel("Number of Shared Drugs", fontsize=14)
plt.title("Shared Drugs Across Disease Pairs", fontsize=16, fontweight="bold")
#plt.yscale("log")  # Log scale for better visibility
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()
# Out:
# /var/folders/0b/z0_jtrl111x5sn006y224x0w0000gq/T/ipykernel_3553/1331459011.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="Category", y="Shared Drugs",
# /var/folders/0b/z0_jtrl111x5sn006y224x0w0000gq/T/ipykernel_3553/1331459011.py:40: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(data=df, x="Category", y="Shared Drugs",

# %%
#Let's import the dictionary with the approved drugs-genes annotations from DrugBank
with open('input/fda_approved_drug_gene_name_drugbank_2023.pickle', 'rb') as handle:
    fda_approved_drgs_dict = pk.load(handle)

#Let's import the diseases
with open('output/allsources_icd_gene_dict_unified.pickle', 'rb') as handle:
    icd_genes_dict = pk.load(handle)

# %%
genetic_background = set([x for xs in list(icd_genes_dict.values()) for x in xs]).union(set([x for xs in list(fda_approved_drgs_dict.values()) for x in xs]))
len(genetic_background)
# Out:
# 18950

# %%
#Let's check that the amount of diseases that have approved/indicated drugs also from a molecular point of view

#First, we need to find the statistically significant disease-drug associations:
drug_intersection_pval_dict = {}
drug_intersection_fdr_dict = {}
drug_intersection_sigfdr_dict = {}

for dis,genelist_A in icd_genes_dict.items():
    for drug,genelist_B in fda_approved_drgs_dict.items():
        drug_intersection_pval = float(fisher_test(set(genelist_A),set(genelist_B),len(genetic_background)))
        drug_intersection_pval_dict[(dis,drug)] = drug_intersection_pval
        
drug_intersection_adj_pval_list = fdr_adjustment(list(drug_intersection_pval_dict.values()),0.05)
pair_list=list(drug_intersection_pval_dict.keys())
for i in range(len(drug_intersection_adj_pval_list)):
    drug_intersection_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

for dis_pair,fdr in drug_intersection_fdr_dict.items():
    if fdr<0.05:
        drug_intersection_sigfdr_dict[dis_pair] = fdr

dis_mol_sig_drug_dict = {}
for dis,genelist_A in icd_genes_dict.items():
    drug_list = []
    for dis_pair in drug_intersection_sigfdr_dict.keys():
        if dis==dis_pair[0]:
            drug_list.append(dis_pair[1])
    if len(drug_list)>0:
        dis_mol_sig_drug_dict[dis] = drug_list
        
print(len(dis_mol_sig_drug_dict))
# Out:
# 757

# %%
disease_drug_mol_df = pd.DataFrame()

dis_list = []
drug_list = []
fdr_list = []
indication_list = []


for dis_drug,fdr in drug_intersection_sigfdr_dict.items():
    dis = dis_drug[0]
    drug = dis_drug[1]
    dis_list.append(dis)
    drug_list.append(drug)
    fdr_list.append(str(fdr))
    try:
        if drug in disease_approveddrugs_dict[dis]:
            indication_list.append(True)
        else:
            indication_list.append(False)
    except:
        indication_list.append(False)


disease_drug_mol_df["Disease"] = dis_list
disease_drug_mol_df["Drug"] = drug_list
disease_drug_mol_df["FDR (molecular overlap)"] = fdr_list
disease_drug_mol_df["Reported indication"] = indication_list

disease_drug_mol_df.head()
# Out:
#   Disease                            Drug FDR (molecular overlap)  \
# 0     B59                    Pomalidomide   0.0014543341174410801
# 1     B59  Foreskin fibroblast (neonatal)    0.008136347179040073
# 2     B59           Peginterferon alfa-2b    0.038528916336211236
# 3     B59              Interferon beta-1b      0.0147884840585972
# 4     B59              Interferon alfa-2b      0.0147884840585972
#
#    Reported indication
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False

# %%
disease_drug_mol_df.to_csv("output/Supp_Tab5_disease_molecular_drugs_df.csv")

# %%
#Let's check that the amount of diseases that have approved/indicated drugs also from a molecular point of view

disease_approveddrugs_shared_mol_pval_dict = {}
disease_approveddrugs_shared_mol_fdr_dict = {}
disease_approveddrugs_shared_mol_sigfdr_dict = {}

for disA,druglist in disease_approveddrugs_dict.items():
    try:
        drug_overlap_pval = float(fisher_test(set(druglist),set(dis_mol_sig_drug_dict[disA]),len(tot_drug_list)))
        disease_approveddrugs_shared_mol_pval_dict[disA]=drug_overlap_pval
    except:
        pass
    
drug_intersection_adj_pval_list = fdr_adjustment(list(disease_approveddrugs_shared_mol_pval_dict.values()),0.05)
pair_list=list(disease_approveddrugs_shared_mol_pval_dict.keys())
for i in range(len(drug_intersection_adj_pval_list)):
    disease_approveddrugs_shared_mol_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

for dis_pair,fdr in disease_approveddrugs_shared_mol_fdr_dict.items():
    if fdr<0.05:
        disease_approveddrugs_shared_mol_sigfdr_dict[dis_pair] = fdr


print(len(disease_approveddrugs_shared_mol_sigfdr_dict))
# Out:
# 6

# %%
#Let's check that the amount of diseases that have approved/indicated drugs also from a molecular point of view

disease_approveddrugs_shared_mol_oneshared_dict = []

for disA,druglist in disease_approveddrugs_dict.items():
    try:
        drug_overlap = len(set(druglist)&set(dis_mol_sig_drug_dict[disA]))
        if drug_overlap>0:
            disease_approveddrugs_shared_mol_oneshared_dict.append(disA)
    except:
        pass

print(len(disease_approveddrugs_shared_mol_oneshared_dict))
# Out:
# 65

# %%
len(disease_approveddrugs_dict)
# Out:
# 260

# %%
disease_approveddrugs_dict["N80"]
# Out:
# ['Leuprolide',
#  'Goserelin',
#  'Medroxyprogesterone acetate',
#  'Nafarelin',
#  'Norethisterone',
#  'Danazol',
#  'Buserelin',
#  'Dienogest',
#  'Gestrinone']

# %%
len(dis_mol_sig_drug_dict["N80"])
# Out:
# 55

# %%
#Let's do the same for the trajectories

# %%
with open('output/male_trajectories_dict_filtered_unique_agglomerated_genes.pickle', 'rb') as handle:
    male_trajectories_dict_filtered_unique_agglomerated_genes = pk.load(handle)
with open('output/female_trajectories_dict_filtered_unique_agglomerated_genes.pickle', 'rb') as handle:
    female_trajectories_dict_filtered_unique_agglomerated_genes = pk.load(handle)

# %%
#Let's check that the amount of diseases that have approved/indicated drugs also from a molecular point of view

#First, we need to find the statistically significant disease-drug associations:
male_trajectories_dict_filtered_unique_drug_intersection_pval_dict = {}
male_trajectories_dict_filtered_unique_drug_intersection_fdr_dict = {}
male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict = {}

for dis,genelist_A in male_trajectories_dict_filtered_unique_agglomerated_genes.items():
    for drug,genelist_B in fda_approved_drgs_dict.items():
        drug_intersection_pval = float(fisher_test(set(genelist_A),set(genelist_B),len(genetic_background)))
        male_trajectories_dict_filtered_unique_drug_intersection_pval_dict[(dis,drug)] = drug_intersection_pval
        
drug_intersection_adj_pval_list = fdr_adjustment(list(male_trajectories_dict_filtered_unique_drug_intersection_pval_dict.values()),0.05)
pair_list=list(male_trajectories_dict_filtered_unique_drug_intersection_pval_dict.keys())
for i in range(len(drug_intersection_adj_pval_list)):
    male_trajectories_dict_filtered_unique_drug_intersection_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

for dis_pair,fdr in male_trajectories_dict_filtered_unique_drug_intersection_fdr_dict.items():
    if fdr<0.05:
        male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict[dis_pair] = fdr

male_trajectories_dict_filtered_unique_mol_sig_drug_dict = {}
for dis,genelist_A in male_trajectories_dict_filtered_unique_agglomerated_genes.items():
    drug_list = []
    for dis_pair in male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict.keys():
        if dis==dis_pair[0]:
            drug_list.append(dis_pair[1])
    if len(drug_list)>0:
        male_trajectories_dict_filtered_unique_mol_sig_drug_dict[dis] = drug_list
        
print(len(male_trajectories_dict_filtered_unique_mol_sig_drug_dict))
# Out:
# 311

# %%
male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df = pd.DataFrame()

trj_list = []
dis_list = []
drug_list = []
fdr_list = []


for trj_drug,fdr in male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict.items():
    trj = trj_drug[0]
    drug = trj_drug[1]
    dislist = male_trajectories_dict_filtered_unique[trj]
    trj_list.append(trj)
    dis_list.append(str(dislist))
    drug_list.append(drug)
    fdr_list.append(str(fdr))


male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["Trajectory"]=trj_list
male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["Disease list"]=dis_list
male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["Drug"]=drug_list
male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["FDR"]=fdr_list

male_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df.to_csv("output/male_trj_mol_drug.csv")

# %%
#Let's check that the amount of diseases that have approved/indicated drugs also from a molecular point of view

#First, we need to find the statistically significant disease-drug associations:
female_trajectories_dict_filtered_unique_drug_intersection_pval_dict = {}
female_trajectories_dict_filtered_unique_drug_intersection_fdr_dict = {}
female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict = {}

for dis,genelist_A in female_trajectories_dict_filtered_unique_agglomerated_genes.items():
    for drug,genelist_B in fda_approved_drgs_dict.items():
        drug_intersection_pval = float(fisher_test(set(genelist_A),set(genelist_B),len(genetic_background)))
        female_trajectories_dict_filtered_unique_drug_intersection_pval_dict[(dis,drug)] = drug_intersection_pval
        
drug_intersection_adj_pval_list = fdr_adjustment(list(female_trajectories_dict_filtered_unique_drug_intersection_pval_dict.values()),0.05)
pair_list=list(female_trajectories_dict_filtered_unique_drug_intersection_pval_dict.keys())
for i in range(len(drug_intersection_adj_pval_list)):
    female_trajectories_dict_filtered_unique_drug_intersection_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

for dis_pair,fdr in female_trajectories_dict_filtered_unique_drug_intersection_fdr_dict.items():
    if fdr<0.05:
        female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict[dis_pair] = fdr

female_trajectories_dict_filtered_unique_mol_sig_drug_dict = {}
for dis,genelist_A in female_trajectories_dict_filtered_unique_agglomerated_genes.items():
    drug_list = []
    for dis_pair in female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict.keys():
        if dis==dis_pair[0]:
            drug_list.append(dis_pair[1])
    if len(drug_list)>0:
        female_trajectories_dict_filtered_unique_mol_sig_drug_dict[dis] = drug_list
        
print(len(female_trajectories_dict_filtered_unique_mol_sig_drug_dict))
# Out:
# 294

# %%
female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df = pd.DataFrame()

trj_list = []
dis_list = []
drug_list = []
fdr_list = []


for trj_drug,fdr in female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_dict.items():
    trj = trj_drug[0]
    drug = trj_drug[1]
    dislist = female_trajectories_dict_filtered_unique[trj]
    trj_list.append(trj)
    dis_list.append(str(dislist))
    drug_list.append(drug)
    fdr_list.append(str(fdr))


female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["Trajectory"]=trj_list
female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["Disease list"]=dis_list
female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["Drug"]=drug_list
female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df["FDR"]=fdr_list

female_trajectories_dict_filtered_unique_drug_intersection_sigfdr_df.to_csv("output/female_trj_mol_drug.csv")

# %%
female_trajectories_dict_filtered_unique_mol_sig_drug_dict
# Out:
# {'1': ['Vandetanib',
#   'Nicotine',
#   'Methadone',
#   'Meperidine',
#   'Quinine',
#   'Clonidine',
#   'Verapamil',
#   'Ofloxacin',
#   'Pazopanib',
#   'Loperamide',
#   'Procainamide',
#   'Tiotropium',
#   'Ruxolitinib',
#   'Tocofersolan',
#   'Guanidine',
#   'Solriamfetol'],
#  '2': ['Human C1-esterase inhibitor',
#   'Kappadione',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Linzagolix',
#   'Caffeine',
#   'Nevirapine',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Imatinib',
#   'Estrone',
#   'Verapamil',
#   'Tamoxifen',
#   'Etoposide',
#   'Ethanol',
#   'Azathioprine',
#   'Rifampicin',
#   'Pimozide',
#   'Nifedipine',
#   'Ofloxacin',
#   'Orphenadrine',
#   'Flunarizine',
#   'Asenapine',
#   'Pazopanib',
#   'Vemurafenib',
#   'Human thrombin',
#   'Nelfinavir',
#   'Indinavir',
#   'Venlafaxine',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Hydroxyzine',
#   'Vinblastine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Loperamide',
#   'Atorvastatin',
#   'Sertraline',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Iloperidone',
#   'Ripretinib',
#   'Glimepiride',
#   'Tenoxicam',
#   'Montelukast',
#   'Zidovudine',
#   'Voriconazole',
#   'Losartan',
#   'Metronidazole',
#   'Sulfamethoxazole',
#   'Glyburide',
#   'Ibuprofen',
#   'Atovaquone',
#   'Zopiclone',
#   'Budesonide',
#   'Lacosamide',
#   'Parecoxib',
#   'Ticagrelor',
#   'Ruxolitinib',
#   'Regorafenib',
#   'Enzalutamide',
#   'Ceritinib',
#   'Lumacaftor',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Rivaroxaban',
#   'Calcium Phosphate',
#   'Calcium phosphate dihydrate',
#   'Pravastatin',
#   'Azithromycin',
#   'Ziprasidone',
#   'Cabergoline',
#   'Medrysone',
#   'Topiramate',
#   'Nisoldipine',
#   'Methotrexate',
#   'Daunorubicin',
#   'Vardenafil',
#   'Ceftriaxone',
#   'Indacaterol',
#   'Tolvaptan',
#   'Bosutinib',
#   'Ivacaftor',
#   'Nintedanib',
#   'Tenofovir alafenamide',
#   'Elbasvir',
#   'Tocofersolan',
#   'Sulfasalazine',
#   'Bumetanide',
#   'Flufenamic acid',
#   'Disulfiram',
#   'Rimexolone',
#   'Levocetirizine',
#   'Methyltestosterone',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Polythiazide',
#   'Cefazolin',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Pentaerythritol tetranitrate',
#   'Loxapine',
#   'Bendroflumethiazide',
#   'Sodium ferric gluconate complex'],
#  '3': ['Human C1-esterase inhibitor',
#   'Kappadione',
#   'Moroctocog alfa',
#   'Turoctocog alfa pegol',
#   'Cetuximab',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Amitriptyline',
#   'Meperidine',
#   'Duloxetine',
#   'Imatinib',
#   'Ethanol',
#   'Azathioprine',
#   'Nifedipine',
#   'Ofloxacin',
#   'Orphenadrine',
#   'Flunarizine',
#   'Asenapine',
#   'Human thrombin',
#   'Fluphenazine',
#   'Trimipramine',
#   'Loperamide',
#   'Dronedarone',
#   'Glimepiride',
#   'Tenoxicam',
#   'Zidovudine',
#   'Glyburide',
#   'Ibuprofen',
#   'Budesonide',
#   'Regorafenib',
#   'Calcium Phosphate',
#   'Calcium phosphate dihydrate',
#   'Pravastatin',
#   'Cabergoline',
#   'Ceftriaxone',
#   'Bosutinib',
#   'Nintedanib',
#   'Sulfasalazine',
#   'Bumetanide',
#   'Flufenamic acid',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Polythiazide',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Norepinephrine',
#   'Pentaerythritol tetranitrate',
#   'Loxapine',
#   'Bendroflumethiazide',
#   'Sodium ferric gluconate complex'],
#  '5': ['Enoxaparin',
#   'Kappadione',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Amitriptyline',
#   'Meperidine',
#   'Imatinib',
#   'Verapamil',
#   'Ethanol',
#   'Azathioprine',
#   'Nifedipine',
#   'Flunarizine',
#   'Human thrombin',
#   'Amoxapine',
#   'Vinblastine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Loperamide',
#   'Dronedarone',
#   'Ripretinib',
#   'Glimepiride',
#   'Glyburide',
#   'Zopiclone',
#   'Budesonide',
#   'Regorafenib',
#   'Bosutinib',
#   'Nintedanib',
#   'Sulfasalazine',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Pentaerythritol tetranitrate',
#   'Bendroflumethiazide',
#   'Sodium ferric gluconate complex'],
#  '6': ['Nabumetone',
#   'Tolmetin',
#   'Cisplatin',
#   'Carboplatin',
#   'Capsaicin',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Clozapine',
#   'Haloperidol',
#   'Clonidine',
#   'Etoposide',
#   'Mefenamic acid',
#   'Asenapine',
#   'Trimipramine',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Ketorolac',
#   'Tenoxicam',
#   'Zopiclone',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Ergotamine',
#   'Desmopressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Loxapine',
#   'Racepinephrine',
#   'Brimonidine',
#   'Pizotifen',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine'],
#  '7': ['Human C1-esterase inhibitor',
#   'Kappadione',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Danazol',
#   'Caffeine',
#   'Nevirapine',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Imatinib',
#   'Estrone',
#   'Verapamil',
#   'Tamoxifen',
#   'Etoposide',
#   'Ethanol',
#   'Azathioprine',
#   'Rifampicin',
#   'Pimozide',
#   'Nifedipine',
#   'Orphenadrine',
#   'Flunarizine',
#   'Asenapine',
#   'Pazopanib',
#   'Vemurafenib',
#   'Human thrombin',
#   'Nelfinavir',
#   'Indinavir',
#   'Venlafaxine',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Hydroxyzine',
#   'Vinblastine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Loperamide',
#   'Atorvastatin',
#   'Sertraline',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Hydroxychloroquine',
#   'Dronedarone',
#   'Iloperidone',
#   'Ripretinib',
#   'Glimepiride',
#   'Voriconazole',
#   'Metronidazole',
#   'Sulfamethoxazole',
#   'Glyburide',
#   'Ibuprofen',
#   'Atovaquone',
#   'Zopiclone',
#   'Budesonide',
#   'Lacosamide',
#   'Parecoxib',
#   'Ticagrelor',
#   'Ruxolitinib',
#   'Regorafenib',
#   'Enzalutamide',
#   'Ceritinib',
#   'Lumacaftor',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Rivaroxaban',
#   'Azithromycin',
#   'Ziprasidone',
#   'Cabergoline',
#   'Topiramate',
#   'Nisoldipine',
#   'Daunorubicin',
#   'Vardenafil',
#   'Indacaterol',
#   'Tolvaptan',
#   'Prucalopride',
#   'Bosutinib',
#   'Ivacaftor',
#   'Nintedanib',
#   'Elbasvir',
#   'Tocofersolan',
#   'Sulfasalazine',
#   'Disulfiram',
#   'Rimexolone',
#   'Methyltestosterone',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Pentaerythritol tetranitrate',
#   'Loxapine',
#   'Bendroflumethiazide',
#   'Sodium ferric gluconate complex'],
#  '8': ['Atomoxetine',
#   'Nevirapine',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Methadone',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Nortriptyline',
#   'Clonidine',
#   'Imatinib',
#   'Verapamil',
#   'Tamoxifen',
#   'Perphenazine',
#   'Cyclobenzaprine',
#   'Nifedipine',
#   'Orphenadrine',
#   'Lopinavir',
#   'Thiothixene',
#   'Abiraterone',
#   'Asenapine',
#   'Vemurafenib',
#   'Nelfinavir',
#   'Atenolol',
#   'Hydroxyzine',
#   'Labetalol',
#   'Meclizine',
#   'Hydroxyurea',
#   'Atorvastatin',
#   'Oxamniquine',
#   'Sertraline',
#   'Darunavir',
#   'Practolol',
#   'Hydroxychloroquine',
#   'Dronedarone',
#   'Lumefantrine',
#   'Rilpivirine',
#   'Mirabegron',
#   'Ibrutinib',
#   'Lorpiprazole',
#   'Ripretinib',
#   'Chloramphenicol succinate',
#   'Triprolidine',
#   'Cefpiramide',
#   'Ceftazidime',
#   'Vancomycin',
#   'Echothiophate',
#   'Cefotetan',
#   'Phenindamine',
#   'Iodipamide',
#   'Gadofosveset trisodium',
#   'Chlorcyclizine',
#   'Potassium alum',
#   'Technetium Tc-99m oxidronate',
#   'Cupric oxide',
#   'Arbutin',
#   'Guaiacol',
#   'Bismuth subgallate',
#   'Medium-chain triglycerides',
#   'Patent Blue',
#   'Coccidioides immitis spherule'],
#  '9': ['Enoxaparin',
#   'Kappadione',
#   'Moroctocog alfa',
#   'Turoctocog alfa pegol',
#   'Cetuximab',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Tolmetin',
#   'Cisplatin',
#   'Carboplatin',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Meperidine',
#   'Duloxetine',
#   'Imatinib',
#   'Verapamil',
#   'Etoposide',
#   'Ethanol',
#   'Azathioprine',
#   'Nifedipine',
#   'Ofloxacin',
#   'Human thrombin',
#   'Venlafaxine',
#   'Vinblastine',
#   'Fluphenazine',
#   'Loperamide',
#   'Sertraline',
#   'Dronedarone',
#   'Ripretinib',
#   'Glimepiride',
#   'Tenoxicam',
#   'Zidovudine',
#   'Glyburide',
#   'Ibuprofen',
#   'Zopiclone',
#   'Budesonide',
#   'Regorafenib',
#   'Calcium Phosphate',
#   'Calcium phosphate dihydrate',
#   'Pravastatin',
#   'Cabergoline',
#   'Methotrexate',
#   'Captopril',
#   'Ceftriaxone',
#   'Bosutinib',
#   'Nintedanib',
#   'Sulfasalazine',
#   'Bumetanide',
#   'Flufenamic acid',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Polythiazide',
#   'Cefazolin',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Pentaerythritol tetranitrate',
#   'Loxapine',
#   'Bendroflumethiazide',
#   'Sodium ferric gluconate complex'],
#  '11': ['Pentaerythritol tetranitrate',
#   'Ferrous sulfate anhydrous',
#   'Sodium ferric gluconate complex',
#   'Ferric derisomaltose',
#   'Coccidioides immitis spherule'],
#  '12': ['Pegfilgrastim',
#   'Filgrastim',
#   'Thimerosal',
#   'Hydroxocobalamin',
#   'Pentaerythritol tetranitrate',
#   'Iron',
#   'Ferrous gluconate',
#   'Ferrous succinate',
#   'Ferrous ascorbate',
#   'Ferrous fumarate',
#   'Ferrous glycine sulfate',
#   'Ferrous sulfate anhydrous',
#   'Sodium ferric gluconate complex',
#   'Ferric derisomaltose'],
#  '13': ['Kappadione',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Amitriptyline',
#   'Meperidine',
#   'Imatinib',
#   'Verapamil',
#   'Ethanol',
#   'Azathioprine',
#   'Nifedipine',
#   'Human thrombin',
#   'Vinblastine',
#   'Fluphenazine',
#   'Loperamide',
#   'Dronedarone',
#   'Ripretinib',
#   'Glimepiride',
#   'Glyburide',
#   'Zopiclone',
#   'Budesonide',
#   'Regorafenib',
#   'Ziprasidone',
#   'Cabergoline',
#   'Bosutinib',
#   'Nintedanib',
#   'Sulfasalazine',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Pentaerythritol tetranitrate',
#   'Bendroflumethiazide',
#   'Sodium ferric gluconate complex'],
#  '14': ['Enoxaparin',
#   'Human C1-esterase inhibitor',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Foreskin fibroblast (neonatal)',
#   'Caffeine',
#   'Theophylline',
#   'Clozapine',
#   'Zolpidem',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Ethanol',
#   'Propafenone',
#   'Asenapine',
#   'Midodrine',
#   'Atenolol',
#   'Timolol',
#   'Sotalol',
#   'Carteolol',
#   'Amoxapine',
#   'Doxazosin',
#   'Trimipramine',
#   'Levobunolol',
#   'Metipranolol',
#   'Quetiapine',
#   'Paliperidone',
#   'Practolol',
#   'Oxprenolol',
#   'Dronedarone',
#   'Torasemide',
#   'Glimepiride',
#   'Dicoumarol',
#   'Ketorolac',
#   'Tenoxicam',
#   'Candesartan cilexetil',
#   'Ibuprofen',
#   'Gliclazide',
#   'Zopiclone',
#   'Lacosamide',
#   'Protamine sulfate',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Ergotamine',
#   'Vardenafil',
#   'Terazosin',
#   'Silodosin',
#   'Fenoprofen',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Liraglutide',
#   'Carisoprodol',
#   'Dipivefrin',
#   'Terbutaline',
#   'Abatacept',
#   'Dobutamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Pentaerythritol tetranitrate',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Ribavirin',
#   'Dyphylline',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Pizotifen',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Quinethazone',
#   'Potassium bicarbonate',
#   'Flumazenil',
#   'Enzacamene',
#   'Miglitol'],
#  '15': ['Enoxaparin',
#   'Atomoxetine',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Pomalidomide',
#   'Tolmetin',
#   'Goserelin',
#   'Danazol',
#   'Gestrinone',
#   'Caffeine',
#   'Theophylline',
#   'Conjugated estrogens',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Orphenadrine',
#   'Propafenone',
#   'Aminophylline',
#   'Oxtriphylline',
#   'Asenapine',
#   'Dosulepin',
#   'Menotropins',
#   'Choriogonadotropin alfa',
#   'Midodrine',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Trimipramine',
#   'Minaprine',
#   'Loperamide',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Tapentadol',
#   'Lorpiprazole',
#   'Tenoxicam',
#   'Dorzolamide',
#   'Ibuprofen',
#   'Zopiclone',
#   'Lacosamide',
#   'Protamine sulfate',
#   'Pravastatin',
#   'Ziprasidone',
#   'Cabergoline',
#   'Topiramate',
#   'Prazosin',
#   'Ergotamine',
#   'Vardenafil',
#   'Terazosin',
#   'Ceftriaxone',
#   'Mesalazine',
#   'Fenoprofen',
#   'Bumetanide',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Dipyrithione',
#   'Methysergide',
#   'Levomenthol',
#   'Brinzolamide',
#   'Pasireotide',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Cyproheptadine',
#   'Cefotaxime',
#   'Ephedrine',
#   'Diazoxide',
#   'Dipivefrin',
#   'Terbutaline',
#   'Piperacillin',
#   'Cyclothiazide',
#   'Methazolamide',
#   'Dinoprostone',
#   'Bromodiphenhydramine',
#   'Tazobactam',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Fluciclovine (18F)',
#   'Iron',
#   'Ferrous gluconate',
#   'Ferrous succinate',
#   'Ferrous ascorbate',
#   'Ferrous fumarate',
#   'Ferrous glycine sulfate',
#   'Etomidate',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Dyphylline',
#   'Rizatriptan',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Isometheptene',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Pizotifen',
#   'Nalbuphine',
#   'Levorphanol',
#   'Remifentanil',
#   'Methylnaltrexone',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium carbonate',
#   'Flumazenil',
#   'Enzacamene',
#   'Edotreotide gallium Ga-68'],
#  '16': ['Foreskin keratinocyte (neonatal)',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Aminosalicylic acid',
#   'Tolmetin',
#   'Theophylline',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Orphenadrine',
#   'Propafenone',
#   'Oxtriphylline',
#   'Asenapine',
#   'Dosulepin',
#   'Midodrine',
#   'Atenolol',
#   'Timolol',
#   'Sotalol',
#   'Dextromethorphan',
#   'Carteolol',
#   'Amoxapine',
#   'Doxazosin',
#   'Fluphenazine',
#   'Trimipramine',
#   'Minaprine',
#   'Sertraline',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Levobunolol',
#   'Metipranolol',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Rotigotine',
#   'Tapentadol',
#   'Vilazodone',
#   'Lorpiprazole',
#   'Ketorolac',
#   'Tenoxicam',
#   'Montelukast',
#   'Zopiclone',
#   'Lacosamide',
#   'Ziprasidone',
#   'Cabergoline',
#   'Protriptyline',
#   'Prazosin',
#   'Bisoprolol',
#   'Ergotamine',
#   'Vardenafil',
#   'Dipyridamole',
#   'Terazosin',
#   'Silodosin',
#   'Desmopressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Methysergide',
#   'Salmeterol',
#   'Daridorexant',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Cyproheptadine',
#   'Ephedrine',
#   'Dipivefrin',
#   'Perindopril',
#   'Terbutaline',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Etomidate',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Dyphylline',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Pizotifen',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Flumazenil'],
#  '18': ['Vandetanib',
#   'Atomoxetine',
#   'Pseudoephedrine',
#   'Pomalidomide',
#   'Tolmetin',
#   'Conjugated estrogens',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Mirtazapine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Norethisterone',
#   'Ethanol',
#   'Rifampicin',
#   'Tocainide',
#   'Nifedipine',
#   'Orphenadrine',
#   'Asenapine',
#   'Ulipristal',
#   'Venlafaxine',
#   'Amlodipine',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Galantamine',
#   'Trimipramine',
#   'Loperamide',
#   'Sertraline',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Tapentadol',
#   'Zidovudine',
#   'Dorzolamide',
#   'Ibuprofen',
#   'Zopiclone',
#   'Budesonide',
#   'Lacosamide',
#   'Pravastatin',
#   'Ziprasidone',
#   'Cabergoline',
#   'Medrysone',
#   'Topiramate',
#   'Protriptyline',
#   'Nisoldipine',
#   'Spironolactone',
#   'Methotrexate',
#   'Ergotamine',
#   'Captopril',
#   'Levetiracetam',
#   'Ceftriaxone',
#   'Ketazolam',
#   'Chloramphenicol succinate',
#   'Dolutegravir',
#   'Nintedanib',
#   'Tenofovir alafenamide',
#   'Bumetanide',
#   'Drospirenone',
#   'Dipyrithione',
#   'Brinzolamide',
#   'Rufinamide',
#   'Pasireotide',
#   'Lanreotide',
#   'Daridorexant',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Avibactam',
#   'Benzatropine',
#   'Chlorthalidone',
#   'Ceftazidime',
#   'Cefotaxime',
#   'Acyclovir',
#   'Polythiazide',
#   'Cefazolin',
#   'Ephedrine',
#   'Cupric oxide',
#   'Diazoxide',
#   'Tubocurarine',
#   'Decamethonium',
#   'Piperacillin',
#   'Cyclothiazide',
#   'Methazolamide',
#   'Tazobactam',
#   'Ouabain',
#   'Norepinephrine',
#   'Fluciclovine (18F)',
#   'Etomidate',
#   'Loxapine',
#   'Racepinephrine',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Baclofen',
#   'Serdexmethylphenidate',
#   'Pizotifen',
#   'Nalbuphine',
#   'Levorphanol',
#   'Remifentanil',
#   'Methylnaltrexone',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Quinethazone',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium carbonate',
#   'Flumazenil',
#   'Ziconotide',
#   'Edotreotide gallium Ga-68'],
#  '20': ['Atomoxetine',
#   'Pseudoephedrine',
#   'Tolmetin',
#   'Cefdinir',
#   'Citalopram',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Meperidine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Mefenamic acid',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Famotidine',
#   'Orphenadrine',
#   'Propafenone',
#   'Thiothixene',
#   'Asenapine',
#   'Dosulepin',
#   'Midodrine',
#   'Atenolol',
#   'Timolol',
#   'Sotalol',
#   'Dextromethorphan',
#   'Carteolol',
#   'Amoxapine',
#   'Doxazosin',
#   'Fluphenazine',
#   'Trimipramine',
#   'Minaprine',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Levobunolol',
#   'Metipranolol',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Rotigotine',
#   'Tapentadol',
#   'Vilazodone',
#   'Lorpiprazole',
#   'Ketorolac',
#   'Tenoxicam',
#   'Zidovudine',
#   'Felbamate',
#   'Ibuprofen',
#   'Pravastatin',
#   'Ziprasidone',
#   'Cabergoline',
#   'Protriptyline',
#   'Prazosin',
#   'Bisoprolol',
#   'Ergotamine',
#   'Terazosin',
#   'Nadolol',
#   'Ceftriaxone',
#   'Silodosin',
#   'Desmopressin',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Bumetanide',
#   'Oxaprozin',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Methysergide',
#   'Salmeterol',
#   'Levocetirizine',
#   'Dihydro-alpha-ergocryptine',
#   'Benzatropine',
#   'Cyproheptadine',
#   'Cefotaxime',
#   'Acyclovir',
#   'Levodopa',
#   'Polythiazide',
#   'Cefazolin',
#   'Ephedrine',
#   'Dipivefrin',
#   'Terbutaline',
#   'Tubocurarine',
#   'Piperacillin',
#   'Dinoprostone',
#   'Bromodiphenhydramine',
#   'Tazobactam',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Rizatriptan',
#   'Brimonidine',
#   'Isometheptene',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Pizotifen',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine'],
#  '21': ['Atomoxetine',
#   'Pseudoephedrine',
#   'Disopyramide',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Orphenadrine',
#   'Asenapine',
#   'Dosulepin',
#   'Cevimeline',
#   'Trospium',
#   'Venlafaxine',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Minaprine',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Tiotropium',
#   'Solifenacin',
#   'Dronedarone',
#   'Tapentadol',
#   'Fesoterodine',
#   'Umeclidinium',
#   'Lorpiprazole',
#   'Dorzolamide',
#   'Felbamate',
#   'Zopiclone',
#   'Lacosamide',
#   'Ziprasidone',
#   'Cabergoline',
#   'Topiramate',
#   'Protriptyline',
#   'Prazosin',
#   'Ergotamine',
#   'Carbamoylcholine',
#   'Methysergide',
#   'Brinzolamide',
#   'Trimebutine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Trihexyphenidyl',
#   'Cyproheptadine',
#   'Ephedrine',
#   'Succinylcholine',
#   'Profenamine',
#   'Mivacurium',
#   'Pancuronium',
#   'Pipecuronium',
#   'Aclidinium',
#   'Methazolamide',
#   'Dopamine',
#   'Norepinephrine',
#   'Gallamine triethiodide',
#   'Phenoxybenzamine',
#   'Fluciclovine (18F)',
#   'Etomidate',
#   'Loxapine',
#   'Racepinephrine',
#   'Hyoscyamine',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Baclofen',
#   'Propiomazine',
#   'Molindone',
#   'Oxyphencyclimine',
#   'Procyclidine',
#   'Methscopolamine bromide',
#   'Anisotropine methylbromide',
#   'Homatropine methylbromide',
#   'Dicyclomine',
#   'Brompheniramine',
#   'Bethanechol',
#   'Mepenzolate',
#   'Pizotifen',
#   'Hexocyclium',
#   'Homatropine',
#   'Thonzylamine',
#   'Flavoxate',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium carbonate',
#   'Flumazenil'],
#  '24': ['Pomalidomide',
#   'Tolmetin',
#   'Capsaicin',
#   'Gestrinone',
#   'Citalopram',
#   'Nevirapine',
#   'Ropivacaine',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Quinine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Imatinib',
#   'Etoposide',
#   'Ethanol',
#   'Azelastine',
#   'Rifampicin',
#   'Pimozide',
#   'Orphenadrine',
#   'Asenapine',
#   'Ulipristal',
#   'Perampanel',
#   'Nelfinavir',
#   'Indinavir',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Hydroxyzine',
#   'Delavirdine',
#   'Trimipramine',
#   'Phenelzine',
#   'Atorvastatin',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Halofantrine',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Iloperidone',
#   'Temsirolimus',
#   'Ibrutinib',
#   'Cobicistat',
#   'Lorpiprazole',
#   'Dexchlorpheniramine maleate',
#   'Rupatadine',
#   'Teniposide',
#   'Ketorolac',
#   'Tenoxicam',
#   'Montelukast',
#   'Voriconazole',
#   'Metronidazole',
#   'Felbamate',
#   'Glyburide',
#   'Ibuprofen',
#   'Ifosfamide',
#   'Zopiclone',
#   'Budesonide',
#   'Lacosamide',
#   'Artemether',
#   'Parecoxib',
#   'Ticagrelor',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Rivaroxaban',
#   'Pantoprazole',
#   'Ziprasidone',
#   'Cabergoline',
#   'Medrysone',
#   'Nisoldipine',
#   'Fluticasone propionate',
#   'Daunorubicin',
#   'Ergotamine',
#   'Vardenafil',
#   'Ivacaftor',
#   'Fluticasone furoate',
#   'Idelalisib',
#   'Elbasvir',
#   'Troleandomycin',
#   'Desmopressin',
#   'Fenoprofen',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Alclometasone',
#   'Amcinonide',
#   'Eplerenone',
#   'Azatadine',
#   'Hydrocortamate',
#   'Disulfiram',
#   'Flurandrenolide',
#   'Loteprednol etabonate',
#   'Rimexolone',
#   'Salmeterol',
#   'Clobetasol propionate',
#   'Finasteride',
#   'Nitrazepam',
#   'Rufinamide',
#   'Levocetirizine',
#   'Saxagliptin',
#   'Difluprednate',
#   'Secnidazole',
#   'Clobetasone',
#   'Methylprednisolone hemisuccinate',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Etomidate',
#   'Loxapine',
#   'Racepinephrine',
#   'Ribavirin',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Pizotifen',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Flumazenil'],
#  '25': ['Pseudoephedrine',
#   'Tolmetin',
#   'Caffeine',
#   'Theophylline',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Clozapine',
#   'Phenylephrine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Mefenamic acid',
#   'Propafenone',
#   'Aminophylline',
#   'Oxtriphylline',
#   'Asenapine',
#   'Dosulepin',
#   'Midodrine',
#   'Atenolol',
#   'Timolol',
#   'Sotalol',
#   'Carteolol',
#   'Amoxapine',
#   'Doxazosin',
#   'Trimipramine',
#   'Levobunolol',
#   'Metipranolol',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Ketorolac',
#   'Tenoxicam',
#   'Candesartan cilexetil',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Bisoprolol',
#   'Ergotamine',
#   'Terazosin',
#   'Nadolol',
#   'Silodosin',
#   'Desmopressin',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Levomenthol',
#   'Salmeterol',
#   'Benzatropine',
#   'Ephedrine',
#   'Dipivefrin',
#   'Terbutaline',
#   'Dobutamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Dyphylline',
#   'Brimonidine',
#   'Propiomazine',
#   'Brompheniramine',
#   'Pizotifen',
#   'Thonzylamine',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Bromhexine'],
#  '27': ['Foreskin keratinocyte (neonatal)',
#   'Pomalidomide',
#   'Foreskin fibroblast (neonatal)',
#   'Aminosalicylic acid',
#   'Nabumetone',
#   'Tolmetin',
#   'Cefdinir',
#   'Capsaicin',
#   'Citalopram',
#   'Acetaminophen',
#   'Clozapine',
#   'Imipramine',
#   'Quinine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Etoposide',
#   'Mefenamic acid',
#   'Azelastine',
#   'Pimozide',
#   'Ofloxacin',
#   'Amoxapine',
#   'Hydroxyzine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Procainamide',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Tiotropium',
#   'Iloperidone',
#   'Ketorolac',
#   'Tenoxicam',
#   'Montelukast',
#   'Candesartan cilexetil',
#   'Ibuprofen',
#   'Ruxolitinib',
#   'Ziprasidone',
#   'Cetirizine',
#   'Lenalidomide',
#   'Ergotamine',
#   'Olopatadine',
#   'Prucalopride',
#   'Bosutinib',
#   'Nintedanib',
#   'Desmopressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Dipyrithione',
#   'Dopamine',
#   'Guanidine',
#   'Solriamfetol',
#   'Loxapine',
#   'Propiomazine'],
#  '28': ['Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Foreskin fibroblast (neonatal)',
#   'Aminosalicylic acid',
#   'Tolmetin',
#   'Cefdinir',
#   'Caffeine',
#   'Theophylline',
#   'Disopyramide',
#   'Amitriptyline',
#   'Clozapine',
#   'Meperidine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Orphenadrine',
#   'Aminophylline',
#   'Oxtriphylline',
#   'Asenapine',
#   'Pazopanib',
#   'Dosulepin',
#   'Midodrine',
#   'Trimipramine',
#   'Quetiapine',
#   'Paliperidone',
#   'Tiotropium',
#   'Oxprenolol',
#   'Solifenacin',
#   'Dronedarone',
#   'Fesoterodine',
#   'Umeclidinium',
#   'Montelukast',
#   'Lacosamide',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Ergotamine',
#   'Terazosin',
#   'Mesalazine',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Dipyrithione',
#   'Carbamoylcholine',
#   'Trimebutine',
#   'Benzylpenicilloyl polylysine',
#   'Benzatropine',
#   'Trihexyphenidyl',
#   'Ephedrine',
#   'Profenamine',
#   'Dipivefrin',
#   'Terbutaline',
#   'Aclidinium',
#   'Norepinephrine',
#   'Gallamine triethiodide',
#   'Phenoxybenzamine',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Hyoscyamine',
#   'Dyphylline',
#   'Brimonidine',
#   'Oxyphencyclimine',
#   'Procyclidine',
#   'Methscopolamine bromide',
#   'Anisotropine methylbromide',
#   'Homatropine methylbromide',
#   'Dicyclomine',
#   'Brompheniramine',
#   'Bethanechol',
#   'Mepenzolate',
#   'Pizotifen',
#   'Hexocyclium',
#   'Homatropine',
#   'Thonzylamine',
#   'Buclizine',
#   'Flavoxate',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine'],
#  '29': ['Kappadione',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Amitriptyline',
#   'Meperidine',
#   'Imatinib',
#   'Verapamil',
#   'Ethanol',
#   'Azathioprine',
#   'Nifedipine',
#   'Vemurafenib',
#   'Human thrombin',
#   'Vinblastine',
#   'Fluphenazine',
#   'Loperamide',
#   'Dronedarone',
#   'Ripretinib',
#   'Glimepiride',
#   'Glyburide',
#   'Budesonide',
#   'Regorafenib',
#   'Bosutinib',
#   'Nintedanib',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Pentaerythritol tetranitrate',
#   'Bendroflumethiazide',
#   'Sodium ferric gluconate complex'],
#  '32': ['Afatinib',
#   'Tolmetin',
#   'Caffeine',
#   'Triamterene',
#   'Umeclidinium',
#   'Ketorolac',
#   'Tenoxicam',
#   'Desmopressin',
#   'Fenoprofen',
#   'Oxaprozin',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Carbamoylcholine',
#   'Trimebutine',
#   'Trihexyphenidyl',
#   'Fluoroestradiol F-18',
#   'Succinylcholine',
#   'Mivacurium',
#   'Pancuronium',
#   'Pipecuronium',
#   'Aclidinium',
#   'Hyoscyamine',
#   'Dyphylline',
#   'Lithium carbonate',
#   'Oxyphencyclimine',
#   'Procyclidine',
#   'Methscopolamine bromide',
#   'Anisotropine methylbromide',
#   'Homatropine methylbromide',
#   'Dicyclomine',
#   'Brompheniramine',
#   'Bethanechol',
#   'Pizotifen',
#   'Hexocyclium',
#   'Homatropine',
#   'Thonzylamine',
#   'Quinethazone',
#   'Eugenol',
#   'Enzacamene'],
#  '34': ['Human C1-esterase inhibitor',
#   'Kappadione',
#   'Turoctocog alfa pegol',
#   'Cetuximab',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Danazol',
#   'Gestrinone',
#   'Caffeine',
#   'Disopyramide',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Imatinib',
#   'Estrone',
#   'Verapamil',
#   'Tamoxifen',
#   'Etoposide',
#   'Ethanol',
#   'Azathioprine',
#   'Rifampicin',
#   'Pimozide',
#   'Nifedipine',
#   'Orphenadrine',
#   'Flunarizine',
#   'Asenapine',
#   'Pazopanib',
#   'Ulipristal',
#   'Vemurafenib',
#   'Human thrombin',
#   'Nelfinavir',
#   'Venlafaxine',
#   'Amoxapine',
#   'Hydroxyzine',
#   'Vinblastine',
#   'Trimipramine',
#   'Loperamide',
#   'Atorvastatin',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Iloperidone',
#   'Ripretinib',
#   'Glimepiride',
#   'Desogestrel',
#   'Montelukast',
#   'Losartan',
#   'Metronidazole',
#   'Glyburide',
#   'Ibuprofen',
#   'Zopiclone',
#   'Budesonide',
#   'Avanafil',
#   'Ticagrelor',
#   'Pitavastatin',
#   'Ruxolitinib',
#   'Regorafenib',
#   'Enzalutamide',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Calcium Phosphate',
#   'Calcium phosphate dihydrate',
#   'Pravastatin',
#   'Ziprasidone',
#   'Cabergoline',
#   'Medrysone',
#   'Topiramate',
#   'Nisoldipine',
#   'Prazosin',
#   'Ergotamine',
#   'Vardenafil',
#   'Dipyridamole',
#   'Ceftriaxone',
#   'Silodosin',
#   'Bosutinib',
#   'Ivacaftor',
#   'Fluticasone furoate',
#   'Olaparib',
#   'Nintedanib',
#   'Sulfasalazine',
#   'Drospirenone',
#   'Levomenthol',
#   'Clobetasol propionate',
#   'Methyltestosterone',
#   'Flavin adenine dinucleotide',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Ephedrine',
#   'Diazoxide',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Loxapine',
#   'Racepinephrine',
#   'Dyphylline',
#   'Pizotifen',
#   'Fenoldopam',
#   'Quinethazone',
#   'Bendroflumethiazide'],
#  '35': ['Nabumetone',
#   'Tolmetin',
#   'Capsaicin',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Clozapine',
#   'Haloperidol',
#   'Clonidine',
#   'Etoposide',
#   'Mefenamic acid',
#   'Asenapine',
#   'Trimipramine',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Ketorolac',
#   'Tenoxicam',
#   'Ibuprofen',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Ergotamine',
#   'Desmopressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Tafluprost',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Dipyrithione',
#   'Hydrocortamate',
#   'Difluprednate',
#   'Clobetasone',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Loxapine',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Capsicum oleoresin',
#   'Brimonidine',
#   'Diflorasone',
#   'Desoximetasone',
#   'Ulobetasol',
#   'Clocortolone',
#   'Pizotifen',
#   'Levallorphan',
#   'Methylnaltrexone',
#   'Fenoldopam',
#   'Apraclonidine'],
#  '36': ['Nabumetone',
#   'Tolmetin',
#   'Cisplatin',
#   'Carboplatin',
#   'Capsaicin',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Clozapine',
#   'Haloperidol',
#   'Clonidine',
#   'Etoposide',
#   'Mefenamic acid',
#   'Asenapine',
#   'Trimipramine',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Ketorolac',
#   'Tenoxicam',
#   'Zopiclone',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Ergotamine',
#   'Desmopressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Loxapine',
#   'Racepinephrine',
#   'Brimonidine',
#   'Pizotifen',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine'],
#  '37': ['Nafarelin',
#   'Danazol',
#   'Degarelix',
#   'Ganirelix',
#   'Gestrinone',
#   'Amoxapine',
#   'Minaprine',
#   'Zopiclone',
#   'Spironolactone',
#   'Sulfasalazine',
#   'Pertuzumab',
#   'Rituximab',
#   'Ofatumumab',
#   'Tyrothricin',
#   'Etomidate',
#   'Methohexital'],
#  '39': ['Enoxaparin',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Foreskin fibroblast (neonatal)',
#   'Caffeine',
#   'Theophylline',
#   'Clozapine',
#   'Zolpidem',
#   'Imipramine',
#   'Haloperidol',
#   'Clonidine',
#   'Ethanol',
#   'Propafenone',
#   'Asenapine',
#   'Midodrine',
#   'Atenolol',
#   'Timolol',
#   'Sotalol',
#   'Carteolol',
#   'Amoxapine',
#   'Doxazosin',
#   'Trimipramine',
#   'Levobunolol',
#   'Metipranolol',
#   'Quetiapine',
#   'Paliperidone',
#   'Practolol',
#   'Oxprenolol',
#   'Dronedarone',
#   'Torasemide',
#   'Glimepiride',
#   'Dicoumarol',
#   'Ketorolac',
#   'Tenoxicam',
#   'Candesartan cilexetil',
#   'Gliclazide',
#   'Zopiclone',
#   'Lacosamide',
#   'Protamine sulfate',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Ergotamine',
#   'Vardenafil',
#   'Terazosin',
#   'Silodosin',
#   'Fenoprofen',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Liraglutide',
#   'Carisoprodol',
#   'Dipivefrin',
#   'Terbutaline',
#   'Abatacept',
#   'Dobutamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Pentaerythritol tetranitrate',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Ribavirin',
#   'Dyphylline',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Pizotifen',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Quinethazone',
#   'Potassium bicarbonate',
#   'Flumazenil',
#   'Enzacamene',
#   'Miglitol'],
#  '40': ['Enoxaparin',
#   'Atomoxetine',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Tolmetin',
#   'Capsaicin',
#   'Goserelin',
#   'Danazol',
#   'Gestrinone',
#   'Nicotine',
#   'Caffeine',
#   'Theophylline',
#   'Disopyramide',
#   'Conjugated estrogens',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Tamoxifen',
#   'Norethisterone',
#   'Mefenamic acid',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Ethinylestradiol',
#   'Nifedipine',
#   'Propafenone',
#   'Aminophylline',
#   'Gemfibrozil',
#   'Oxtriphylline',
#   'Thiothixene',
#   'Febuxostat',
#   'Eltrombopag',
#   'Asenapine',
#   'Dosulepin',
#   'Menotropins',
#   'Choriogonadotropin alfa',
#   'Midodrine',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Doxazosin',
#   'Labetalol',
#   'Trimipramine',
#   'Minaprine',
#   'Loperamide',
#   'Chlorpheniramine',
#   'Bupropion',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Tapentadol',
#   'Mirabegron',
#   'Lorpiprazole',
#   'Desogestrel',
#   'Tenoxicam',
#   'Zidovudine',
#   'Losartan',
#   'Candesartan cilexetil',
#   'Dorzolamide',
#   'Ibuprofen',
#   'Zopiclone',
#   'Lacosamide',
#   'Protamine sulfate',
#   'Pravastatin',
#   'Ziprasidone',
#   'Cabergoline',
#   'Topiramate',
#   'Prazosin',
#   'Ergotamine',
#   'Vardenafil',
#   'Terazosin',
#   'Ceftriaxone',
#   'Silodosin',
#   'Dolutegravir',
#   'Empagliflozin',
#   'Nintedanib',
#   'Mesalazine',
#   'Fenoprofen',
#   'Bumetanide',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Dipyrithione',
#   'Carbamoylcholine',
#   'Methysergide',
#   'Salmeterol',
#   'Brinzolamide',
#   'Pasireotide',
#   'Trimebutine',
#   'Flavin adenine dinucleotide',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Cyproheptadine',
#   'Cefotaxime',
#   'Acyclovir',
#   'Methyldopa',
#   'Polythiazide',
#   'Ephedrine',
#   'Diazoxide',
#   'Dipivefrin',
#   'Terbutaline',
#   'Tubocurarine',
#   'Decamethonium',
#   'Piperacillin',
#   'Cyclothiazide',
#   'Methazolamide',
#   'Tazobactam',
#   'Amantadine',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Fluciclovine (18F)',
#   'Iron',
#   'Ferrous gluconate',
#   'Ferrous succinate',
#   'Ferrous ascorbate',
#   'Ferrous fumarate',
#   'Ferrous glycine sulfate',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Dyphylline',
#   'Rizatriptan',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Isometheptene',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Mepenzolate',
#   'Pizotifen',
#   'Nalbuphine',
#   'Levorphanol',
#   'Remifentanil',
#   'Methylnaltrexone',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Quinethazone',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium carbonate',
#   'Flumazenil',
#   'Enzacamene',
#   'Edotreotide gallium Ga-68'],
#  '42': ['Enoxaparin',
#   'Human C1-esterase inhibitor',
#   'Kappadione',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Danazol',
#   'Imatinib',
#   'Ethanol',
#   'Nifedipine',
#   'Ofloxacin',
#   'Pazopanib',
#   'Human thrombin',
#   'Loperamide',
#   'Donepezil',
#   'Dronedarone',
#   'Glimepiride',
#   'Regorafenib',
#   'Calcium Phosphate',
#   'Calcium phosphate dihydrate',
#   'Nintedanib',
#   'Sulfasalazine',
#   'Flufenamic acid',
#   'Flavin adenine dinucleotide',
#   'Methylphenobarbital',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Quinidine barbiturate',
#   'Eugenol',
#   'Enzacamene',
#   'Gallium citrate Ga-67',
#   'Ferrous sulfate anhydrous',
#   'Sodium ferric gluconate complex'],
#  '43': ['Vandetanib',
#   'Afatinib',
#   'Osimertinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Atomoxetine',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Pomalidomide',
#   'Capsaicin',
#   'Nicotine',
#   'Citalopram',
#   'Conjugated estrogens',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Estrone',
#   'Verapamil',
#   'Tamoxifen',
#   'Etoposide',
#   'Perphenazine',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Ethinylestradiol',
#   'Pimozide',
#   'Nifedipine',
#   'Orphenadrine',
#   'Thiothixene',
#   'Flunarizine',
#   'Asenapine',
#   'Benzyl alcohol',
#   'Dosulepin',
#   'Venlafaxine',
#   'Amlodipine',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Doxazosin',
#   'Fluphenazine',
#   'Trimipramine',
#   'Phenelzine',
#   'Minaprine',
#   'Loperamide',
#   'Donepezil',
#   'Sertraline',
#   'Chlorpheniramine',
#   'Bupropion',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Tiotropium',
#   'Solifenacin',
#   'Dronedarone',
#   'Iloperidone',
#   'Rotigotine',
#   'Tapentadol',
#   'Vilazodone',
#   'Fesoterodine',
#   'Rilpivirine',
#   'Umeclidinium',
#   'Lorpiprazole',
#   'Ripretinib',
#   'Dorzolamide',
#   'Felbamate',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Mitotane',
#   'Ziprasidone',
#   'Cabergoline',
#   'Topiramate',
#   'Protriptyline',
#   'Prazosin',
#   'Lenalidomide',
#   'Ergotamine',
#   'Terazosin',
#   'Ergometrine',
#   'Colchicine',
#   'Silodosin',
#   'Polyethylene glycol 400',
#   'Tocofersolan',
#   'alpha-Tocopherol acetate',
#   'Methysergide',
#   'Disulfiram',
#   'Trimebutine',
#   'Dihydro-alpha-ergocryptine',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Trihexyphenidyl',
#   'Cyproheptadine',
#   'Methyldopa',
#   'Levodopa',
#   'Ephedrine',
#   'Dipivefrin',
#   'Aclidinium',
#   'Amantadine',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Gallamine triethiodide',
#   'Phenoxybenzamine',
#   'Solriamfetol',
#   'Rocuronium',
#   'Loxapine',
#   'Racepinephrine',
#   'Rizatriptan',
#   'Isocarboxazid',
#   'Pargyline',
#   'Tedizolid phosphate',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Homatropine methylbromide',
#   'Brompheniramine',
#   'Bethanechol',
#   'Pizotifen',
#   'Homatropine',
#   'Thonzylamine',
#   'Nalbuphine',
#   'Levorphanol',
#   'Remifentanil',
#   'Methylnaltrexone',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine'],
#  '45': ['Atomoxetine',
#   'Pseudoephedrine',
#   'Nicotine',
#   'Caffeine',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Orphenadrine',
#   'Thiothixene',
#   'Asenapine',
#   'Dosulepin',
#   'Cevimeline',
#   'Trospium',
#   'Midodrine',
#   'Venlafaxine',
#   'Atenolol',
#   'Timolol',
#   'Amlodipine',
#   'Sotalol',
#   'Dextromethorphan',
#   'Carteolol',
#   'Amoxapine',
#   'Doxazosin',
#   'Fluphenazine',
#   'Trimipramine',
#   'Minaprine',
#   'Loperamide',
#   'Sertraline',
#   'Bupropion',
#   'Escitalopram',
#   'Levobunolol',
#   'Metipranolol',
#   'Quetiapine',
#   'Paliperidone',
#   'Tiotropium',
#   'Oxprenolol',
#   'Solifenacin',
#   'Dronedarone',
#   'Iloperidone',
#   'Rotigotine',
#   'Tapentadol',
#   'Vilazodone',
#   'Fesoterodine',
#   'Umeclidinium',
#   'Lorpiprazole',
#   'Ziprasidone',
#   'Cabergoline',
#   'Prazosin',
#   'Ergotamine',
#   'Carbamoylcholine',
#   'Methysergide',
#   'Trimebutine',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Levodopa',
#   'Ephedrine',
#   'Dipivefrin',
#   'Decamethonium',
#   'Amantadine',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Gallamine triethiodide',
#   'Phenoxybenzamine',
#   'Loxapine',
#   'Arbutamine',
#   'Racepinephrine',
#   'Hyoscyamine',
#   'Dyphylline',
#   'Brimonidine',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Procyclidine',
#   'Homatropine methylbromide',
#   'Bethanechol',
#   'Pizotifen',
#   'Hexocyclium',
#   'Nalbuphine',
#   'Levorphanol',
#   'Remifentanil',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine'],
#  '46': ['Atomoxetine',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Danazol',
#   'Gestrinone',
#   'Citalopram',
#   'Conjugated estrogens',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Nifedipine',
#   'Orphenadrine',
#   'Propafenone',
#   'Thiothixene',
#   'Estrone sulfate',
#   'Asenapine',
#   'Ulipristal',
#   'Dosulepin',
#   'Midodrine',
#   'Venlafaxine',
#   'Atenolol',
#   'Timolol',
#   'Sotalol',
#   'Dextromethorphan',
#   'Carteolol',
#   'Amoxapine',
#   'Doxazosin',
#   'Labetalol',
#   'Fluphenazine',
#   'Galantamine',
#   'Trimipramine',
#   'Minaprine',
#   'Loperamide',
#   'Donepezil',
#   'Sertraline',
#   'Chlorpheniramine',
#   'Bupropion',
#   'Escitalopram',
#   'Levobunolol',
#   'Metipranolol',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Rotigotine',
#   'Tapentadol',
#   'Vilazodone',
#   'Lorpiprazole',
#   'Desogestrel',
#   'Felbamate',
#   'Zopiclone',
#   'Lacosamide',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Ziprasidone',
#   'Cabergoline',
#   'Protriptyline',
#   'Nisoldipine',
#   'Spironolactone',
#   'Prazosin',
#   'Fluticasone propionate',
#   'Bisoprolol',
#   'Ergotamine',
#   'Terazosin',
#   'Nadolol',
#   'Silodosin',
#   'Fluticasone furoate',
#   'Drospirenone',
#   'Carbamoylcholine',
#   'Methysergide',
#   'Ethynodiol diacetate',
#   'Clobetasol propionate',
#   'Trimebutine',
#   'Dihydro-alpha-ergocryptine',
#   'Daridorexant',
#   'Flavin adenine dinucleotide',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Cyproheptadine',
#   'Methyldopa',
#   'Levodopa',
#   'Ephedrine',
#   'Fluoroestradiol F-18',
#   'Pentagastrin',
#   'Profenamine',
#   'Dipivefrin',
#   'Benzonatate',
#   'Terbutaline',
#   'Demecarium',
#   'Cyclopentolate',
#   'Edrophonium',
#   'Ambenonium',
#   'Tubocurarine',
#   'Decamethonium',
#   'Aclidinium',
#   'Amantadine',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Gallamine triethiodide',
#   'Phenoxybenzamine',
#   'Solriamfetol',
#   'Etomidate',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Rizatriptan',
#   'Isocarboxazid',
#   'Pargyline',
#   'Tedizolid phosphate',
#   'Quinidine barbiturate',
#   'Lithium citrate',
#   'Lithium carbonate',
#   'Brimonidine',
#   'Isometheptene',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Brompheniramine',
#   'Pizotifen',
#   'Thonzylamine',
# ...
#   'Aminophylline',
#   'Oxtriphylline',
#   'Insulin detemir',
#   'Estrone sulfate',
#   'Flunarizine',
#   'Asenapine',
#   'Ulipristal',
#   'Insulin degludec',
#   'Anistreplase',
#   'Prothrombin',
#   'Human thrombin',
#   'Thrombin alfa',
#   'Midodrine',
#   'Venlafaxine',
#   'Atenolol',
#   'Amlodipine',
#   'Sotalol',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Hydroxyzine',
#   'Doxazosin',
#   'Trimipramine',
#   'Loperamide',
#   'Donepezil',
#   'Atorvastatin',
#   'Chlorpheniramine',
#   'Halofantrine',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Mirabegron',
#   'Ibrutinib',
#   'Cobicistat',
#   'Lorpiprazole',
#   'Ripretinib',
#   'Berotralstat',
#   'Desogestrel',
#   'Teniposide',
#   'Tenoxicam',
#   'Zidovudine',
#   'Losartan',
#   'Glyburide',
#   'Ibuprofen',
#   'Zopiclone',
#   'Lacosamide',
#   'Avanafil',
#   'Ticagrelor',
#   'Enzalutamide',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Rivaroxaban',
#   'Pravastatin',
#   'Pantoprazole',
#   'Ziprasidone',
#   'Cabergoline',
#   'Medrysone',
#   'Topiramate',
#   'Nisoldipine',
#   'Spironolactone',
#   'Prazosin',
#   'Methotrexate',
#   'Fluticasone propionate',
#   'Bisoprolol',
#   'Daunorubicin',
#   'Ergotamine',
#   'Vardenafil',
#   'Terazosin',
#   'Captopril',
#   'Ceftriaxone',
#   'Silodosin',
#   'Tolvaptan',
#   'Cabazitaxel',
#   'Fluticasone furoate',
#   'Riociguat',
#   'Idelalisib',
#   'Olaparib',
#   'Elbasvir',
#   'Troleandomycin',
#   'Desmopressin',
#   'Vasopressin',
#   'Lypressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Bumetanide',
#   'Drospirenone',
#   'Flufenamic acid',
#   'Amcinonide',
#   'Methylergometrine',
#   'Eplerenone',
#   'Indapamide',
#   'Ethynodiol diacetate',
#   'Levomenthol',
#   'Loteprednol etabonate',
#   'Rimexolone',
#   'Salmeterol',
#   'Clobetasol propionate',
#   'Brinzolamide',
#   'Hydralazine',
#   'Levocetirizine',
#   'Pasireotide',
#   'Methyltestosterone',
#   'Lanreotide',
#   'Dienogest',
#   'Norethynodrel',
#   'Norgestrel',
#   'Isosorbide mononitrate',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Chlorthalidone',
#   'Cefotaxime',
#   'Didanosine',
#   'Polythiazide',
#   'Cefazolin',
#   'Ephedrine',
#   'Fluoroestradiol F-18',
#   'Diazoxide',
#   'Dipivefrin',
#   'Terbutaline',
#   'Cyclothiazide',
#   'Methazolamide',
#   'Dinoprostone',
#   'Ouabain',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Loxapine',
#   'Arbutamine',
#   'Racepinephrine',
#   'Dyphylline',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Netarsudil',
#   'Pizotifen',
#   'Epoprostenol',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Quinethazone',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium carbonate',
#   'Flumazenil',
#   'Eugenol',
#   'Enzacamene',
#   'Misoprostol',
#   'Edotreotide gallium Ga-68'],
#  '436': ['Enoxaparin',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Foreskin keratinocyte (neonatal)',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Pomalidomide',
#   'Foreskin fibroblast (neonatal)',
#   'Nabumetone',
#   'Tolmetin',
#   'Cisplatin',
#   'Capsaicin',
#   'Danazol',
#   'Gestrinone',
#   'Nevirapine',
#   'Theophylline',
#   'Disopyramide',
#   'Ropivacaine',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Nitric Oxide',
#   'Meperidine',
#   'Imipramine',
#   'Quinine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Imatinib',
#   'Estrone',
#   'Verapamil',
#   'Tamoxifen',
#   'Warfarin',
#   'Norethisterone',
#   'Clopidogrel',
#   'Etoposide',
#   'Mefenamic acid',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Azelastine',
#   'Azathioprine',
#   'Rifampicin',
#   'Tocainide',
#   'Norfloxacin',
#   'Pimozide',
#   'Nifedipine',
#   'Orphenadrine',
#   'Propafenone',
#   'Insulin detemir',
#   'Asenapine',
#   'Apixaban',
#   'Ulipristal',
#   'Perampanel',
#   'Insulin degludec',
#   'Anistreplase',
#   'Midodrine',
#   'Nelfinavir',
#   'Indinavir',
#   'Atenolol',
#   'Timolol',
#   'Amlodipine',
#   'Sotalol',
#   'Dextromethorphan',
#   'Carteolol',
#   'Amoxapine',
#   'Hydroxyzine',
#   'Doxazosin',
#   'Labetalol',
#   'Simvastatin',
#   'Delavirdine',
#   'Trimipramine',
#   'Meclizine',
#   'Phenelzine',
#   'Loperamide',
#   'Atorvastatin',
#   'Fluvastatin',
#   'Sertraline',
#   'Chlorpheniramine',
#   'Bicalutamide',
#   'Escitalopram',
#   'Levobunolol',
#   'Metipranolol',
#   'Halofantrine',
#   'Quetiapine',
#   'Darunavir',
#   'Paliperidone',
#   'Oxprenolol',
#   'Hydroxychloroquine',
#   'Dronedarone',
#   'Iloperidone',
#   'Tapentadol',
#   'Temsirolimus',
#   'Mirabegron',
#   'Naloxegol',
#   'Ibrutinib',
#   'Cobicistat',
#   'Lorpiprazole',
#   'Dexchlorpheniramine maleate',
#   'Rupatadine',
#   'Torasemide',
#   'Dicoumarol',
#   'Teniposide',
#   'Ketorolac',
#   'Tenoxicam',
#   'Montelukast',
#   'Voriconazole',
#   'Losartan',
#   'Candesartan cilexetil',
#   'Dorzolamide',
#   'Metronidazole',
#   'Felbamate',
#   'Sulfamethoxazole',
#   'Glyburide',
#   'Ibuprofen',
#   'Gliclazide',
#   'Cyclizine',
#   'Ifosfamide',
#   'Zopiclone',
#   'Budesonide',
#   'Lacosamide',
#   'Avanafil',
#   'Artemether',
#   'Parecoxib',
#   'Ticagrelor',
#   'Enzalutamide',
#   'Macitentan',
#   'Testosterone cypionate',
#   'Testosterone enanthate',
#   'Rivaroxaban',
#   'Protamine sulfate',
#   'Ziprasidone',
#   'Cabergoline',
#   'Medrysone',
#   'Topiramate',
#   'Nisoldipine',
#   'Spironolactone',
#   'Prazosin',
#   'Fluticasone propionate',
#   'Bisoprolol',
#   'Daunorubicin',
#   'Ergotamine',
#   'Olopatadine',
#   'Oxcarbazepine',
#   'Vardenafil',
#   'Terazosin',
#   'Clarithromycin',
#   'Ergometrine',
#   'Ketazolam',
#   'Indacaterol',
#   'Silodosin',
#   'Tolvaptan',
#   'Prucalopride',
#   'Ivacaftor',
#   'Fluticasone furoate',
#   'Riociguat',
#   'Idelalisib',
#   'Olaparib',
#   'Elbasvir',
#   'Grazoprevir',
#   'Troleandomycin',
#   'Desmopressin',
#   'Vasopressin',
#   'Lypressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Dipyrithione',
#   'Dalteparin',
#   'Liraglutide',
#   'Alclometasone',
#   'Amcinonide',
#   'Eplerenone',
#   'Azatadine',
#   'Hydrocortamate',
#   'Indapamide',
#   'Disulfiram',
#   'Flurandrenolide',
#   'Loteprednol etabonate',
#   'Rimexolone',
#   'Salmeterol',
#   'Isotretinoin',
#   'Clobetasol propionate',
#   'Brinzolamide',
#   'Finasteride',
#   'Hydralazine',
#   'Nitrazepam',
#   'Rufinamide',
#   'Levocetirizine',
#   'Saxagliptin',
#   'Methyltestosterone',
#   'Desoxycorticosterone acetate',
#   'Difluprednate',
#   'Vilanterol',
#   'Trimebutine',
#   'Pinaverium',
#   'Dienogest',
#   'Norethynodrel',
#   'Norgestrel',
#   'Secnidazole',
#   'Clobetasone',
#   'Fosnetupitant',
#   'Methylprednisolone hemisuccinate',
#   'Isosorbide mononitrate',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Chlorthalidone',
#   'Triprolidine',
#   'Polythiazide',
#   'Ephedrine',
#   'Phenindamine',
#   'Chlorcyclizine',
#   'Diazoxide',
#   'Dipivefrin',
#   'Terbutaline',
#   'Cyclothiazide',
#   'Methazolamide',
#   'Ouabain',
#   'Dobutamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Pentaerythritol tetranitrate',
#   'Etomidate',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Ribavirin',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Netarsudil',
#   'Propiomazine',
#   'Pizotifen',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Quinethazone',
#   'Potassium gluconate',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium carbonate',
#   'Flumazenil',
#   'Tasonermin'],
#  '437': ['Kappadione',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Nicotine',
#   'Caffeine',
#   'Theophylline',
#   'Disopyramide',
#   'Amitriptyline',
#   'Methadone',
#   'Clozapine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Imatinib',
#   'Estrone',
#   'Verapamil',
#   'Tamoxifen',
#   'Methimazole',
#   'Etoposide',
#   'Ethanol',
#   'Azathioprine',
#   'Pimozide',
#   'Nifedipine',
#   'Ofloxacin',
#   'Orphenadrine',
#   'Propafenone',
#   'Aminophylline',
#   'Oxtriphylline',
#   'Flunarizine',
#   'Asenapine',
#   'Pazopanib',
#   'Vemurafenib',
#   'Dosulepin',
#   'Human thrombin',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Vinblastine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Loperamide',
#   'Sertraline',
#   'Quetiapine',
#   'Paliperidone',
#   'Tiotropium',
#   'Solifenacin',
#   'Dronedarone',
#   'Fesoterodine',
#   'Umeclidinium',
#   'Ripretinib',
#   'Glimepiride',
#   'Dorzolamide',
#   'Glyburide',
#   'Budesonide',
#   'Regorafenib',
#   'Ziprasidone',
#   'Cabergoline',
#   'Topiramate',
#   'Prazosin',
#   'Ergotamine',
#   'Terazosin',
#   'Silodosin',
#   'Bosutinib',
#   'Nintedanib',
#   'Carbamoylcholine',
#   'Trimebutine',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Trihexyphenidyl',
#   'Ephedrine',
#   'Diazoxide',
#   'Aclidinium',
#   'Hydroxocobalamin',
#   'Dopamine',
#   'Norepinephrine',
#   'Gallamine triethiodide',
#   'Phenoxybenzamine',
#   'Pentaerythritol tetranitrate',
#   'Loxapine',
#   'Racepinephrine',
#   'Hyoscyamine',
#   'Dyphylline',
#   'Procyclidine',
#   'Homatropine methylbromide',
#   'Brompheniramine',
#   'Bethanechol',
#   'Pizotifen',
#   'Hexocyclium',
#   'Homatropine',
#   'Thonzylamine',
#   'Phentolamine',
#   'Fenoldopam',
#   'Quinethazone',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium ferric gluconate complex'],
#  '438': ['Kappadione',
#   'Coagulation Factor IX Human',
#   'Turoctocog alfa pegol',
#   'Vandetanib',
#   'Afatinib',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Carboplatin',
#   'Danazol',
#   'Amitriptyline',
#   'Clozapine',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Imatinib',
#   'Estrone',
#   'Verapamil',
#   'Tamoxifen',
#   'Etoposide',
#   'Ethanol',
#   'Azathioprine',
#   'Nifedipine',
#   'Ofloxacin',
#   'Orphenadrine',
#   'Flunarizine',
#   'Febuxostat',
#   'Asenapine',
#   'Pazopanib',
#   'Human thrombin',
#   'Thrombin alfa',
#   'Amoxapine',
#   'Vinblastine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Loperamide',
#   'Sertraline',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Tapentadol',
#   'Ripretinib',
#   'Glimepiride',
#   'Losartan',
#   'Candesartan cilexetil',
#   'Glyburide',
#   'Ibuprofen',
#   'Budesonide',
#   'Ruxolitinib',
#   'Regorafenib',
#   'Ziprasidone',
#   'Cabergoline',
#   'Spironolactone',
#   'Prazosin',
#   'Daunorubicin',
#   'Ergotamine',
#   'Terazosin',
#   'Bosutinib',
#   'Olaparib',
#   'Nintedanib',
#   'Sulfasalazine',
#   'Flavin adenine dinucleotide',
#   'Dalfampridine',
#   'Adapalene',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Acitretin',
#   'Ephedrine',
#   'Diazoxide',
#   'Hydroxocobalamin',
#   'Dobutamine',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Pentaerythritol tetranitrate',
#   'Etomidate',
#   'Loxapine',
#   'Racepinephrine',
#   'Propiomazine',
#   'Pizotifen',
#   'Phentolamine',
#   'Fenoldopam',
#   'Bendroflumethiazide',
#   'Eugenol',
#   'Enzacamene',
#   'Sodium ferric gluconate complex',
#   'Edotreotide gallium Ga-68'],
#  '440': ['Cetuximab',
#   'Foreskin keratinocyte (neonatal)',
#   'Pseudoephedrine',
#   'Amrinone',
#   'Pomalidomide',
#   'Foreskin fibroblast (neonatal)',
#   'Cisplatin',
#   'Caffeine',
#   'Theophylline',
#   'Acetaminophen',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Phenylephrine',
#   'Zolpidem',
#   'Meperidine',
#   'Imipramine',
#   'Duloxetine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Clonidine',
#   'Verapamil',
#   'Etoposide',
#   'Ethanol',
#   'Cyclobenzaprine',
#   'Orphenadrine',
#   'Propafenone',
#   'Oxtriphylline',
#   'Asenapine',
#   'Dosulepin',
#   'Human thrombin',
#   'Thrombin alfa',
#   'Midodrine',
#   'Venlafaxine',
#   'Timolol',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Doxazosin',
#   'Fluphenazine',
#   'Trimipramine',
#   'Minaprine',
#   'Sertraline',
#   'Chlorpheniramine',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Oxprenolol',
#   'Dronedarone',
#   'Iloperidone',
#   'Rotigotine',
#   'Tapentadol',
#   'Lorpiprazole',
#   'Candesartan cilexetil',
#   'Dorzolamide',
#   'Zopiclone',
#   'Lacosamide',
#   'Ziprasidone',
#   'Cabergoline',
#   'Topiramate',
#   'Cetirizine',
#   'Protriptyline',
#   'Nisoldipine',
#   'Prazosin',
#   'Lenalidomide',
#   'Bisoprolol',
#   'Ergotamine',
#   'Vardenafil',
#   'Dipyridamole',
#   'Terazosin',
#   'Captopril',
#   'Silodosin',
#   'Tolvaptan',
#   'Linagliptin',
#   'alpha-Tocopherol acetate',
#   'Desmopressin',
#   'Vasopressin',
#   'Lypressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Oxaprozin',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Dalteparin',
#   'Levomenthol',
#   'Brinzolamide',
#   'Trimebutine',
#   'Adapalene',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Benzatropine',
#   'Cyproheptadine',
#   'Acitretin',
#   'Levodopa',
#   'Ephedrine',
#   'Diazoxide',
#   'Dipivefrin',
#   'Terbutaline',
#   'Pancuronium',
#   'Methazolamide',
#   'Cycloserine',
#   'Amantadine',
#   'Dopamine',
#   'Norepinephrine',
#   'Phenoxybenzamine',
#   'Isoetharine',
#   'Loxapine',
#   'Arbutamine',
#   'Pirbuterol',
#   'Racepinephrine',
#   'DL-Methylephedrine',
#   'Dyphylline',
#   'Quinidine barbiturate',
#   'Brimonidine',
#   'Serdexmethylphenidate',
#   'Propiomazine',
#   'Molindone',
#   'Brompheniramine',
#   'Pizotifen',
#   'Thonzylamine',
#   'Nalbuphine',
#   'Levorphanol',
#   'Remifentanil',
#   'Methylnaltrexone',
#   'Dapiprazole',
#   'Phentolamine',
#   'Fenoldopam',
#   'Apraclonidine',
#   'Bendroflumethiazide',
#   'Benzthiazide',
#   'Sodium carbonate',
#   'Flumazenil'],
#  '441': ['Foreskin keratinocyte (neonatal)',
#   'Abciximab',
#   'Aldesleukin',
#   'Pseudoephedrine',
#   'Pomalidomide',
#   'Foreskin fibroblast (neonatal)',
#   'Nabumetone',
#   'Tolmetin',
#   'Capsaicin',
#   'Acetaminophen',
#   'Etoposide',
#   'Mefenamic acid',
#   'Ketorolac',
#   'Tenoxicam',
#   'Lacosamide',
#   'Desmopressin',
#   'Mesalazine',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Levomenthol',
#   'Coccidioides immitis spherule'],
#  '442': ['Theophylline',
#   'Amitriptyline',
#   'Clozapine',
#   'Mirtazapine',
#   'Meperidine',
#   'Imipramine',
#   'Haloperidol',
#   'Nortriptyline',
#   'Ethanol',
#   'Nifedipine',
#   'Orphenadrine',
#   'Oxtriphylline',
#   'Thiothixene',
#   'Asenapine',
#   'Dosulepin',
#   'Dextromethorphan',
#   'Amoxapine',
#   'Fluphenazine',
#   'Trimipramine',
#   'Minaprine',
#   'Loperamide',
#   'Donepezil',
#   'Escitalopram',
#   'Quetiapine',
#   'Paliperidone',
#   'Dronedarone',
#   'Iloperidone',
#   'Rotigotine',
#   'Tapentadol',
#   'Lorpiprazole',
#   'Felbamate',
#   'Lacosamide',
#   'Ziprasidone',
#   'Cabergoline',
#   'Nisoldipine',
#   'Ergotamine',
#   'Dipyridamole',
#   'Captopril',
#   'Drospirenone',
#   'Methysergide',
#   'Cyproheptadine',
#   'Amantadine',
#   'Loxapine',
#   'Dyphylline',
#   'Ibutilide',
#   'Propiomazine',
#   'Molindone',
#   'Pizotifen',
#   'Nalbuphine',
#   'Levorphanol',
#   'Remifentanil',
#   'Methylnaltrexone'],
#  '444': ['Nabumetone',
#   'Tolmetin',
#   'Capsaicin',
#   'Danazol',
#   'Gestrinone',
#   'Acetaminophen',
#   'Zolpidem',
#   'Mefenamic acid',
#   'Ethanol',
#   'Ulipristal',
#   'Desogestrel',
#   'Ketorolac',
#   'Tenoxicam',
#   'Ibuprofen',
#   'Zopiclone',
#   'Lacosamide',
#   'Mitotane',
#   'Thyroid, porcine',
#   'Spironolactone',
#   'Desmopressin',
#   'Fenoprofen',
#   'Sulfasalazine',
#   'Oxaprozin',
#   'Drospirenone',
#   'Salsalate',
#   'Choline magnesium trisalicylate',
#   'Antrafenine',
#   'Tiaprofenic acid',
#   'Flufenamic acid',
#   'Loxoprofen',
#   'Phenyl salicylate',
#   'Trolamine salicylate',
#   'Menthyl salicylate',
#   'Glycol salicylate',
#   'Ethynodiol diacetate',
#   'Methyltestosterone',
#   'Norgestrel',
#   'Edetate calcium disodium anhydrous',
#   'Carisoprodol',
#   'Methylphenobarbital',
#   'Etomidate',
#   'Quinidine barbiturate',
#   'Flumazenil',
#   'Enzacamene',
#   'Misoprostol']}

# %%
male_trajectories_dict_filtered_unique_with_drugs_dict_explicit = {}

for trj,disset in male_trajectories_dict_filtered_unique_with_drugs_dict.items():
    drug_list = []
    for dis in disset:
        drug_list.extend(disease_approveddrugs_dict[dis])
    male_trajectories_dict_filtered_unique_with_drugs_dict_explicit[trj] = set(drug_list)


female_trajectories_dict_filtered_unique_with_drugs_dict_explicit = {}

for trj,disset in female_trajectories_dict_filtered_unique_with_drugs_dict.items():
    drug_list = []
    for dis in disset:
        drug_list.extend(disease_approveddrugs_dict[dis])
    female_trajectories_dict_filtered_unique_with_drugs_dict_explicit[trj] = set(drug_list)

# %%
#Let's check that the amount of diseases that have approved/indicated drugs also from a molecular point of view

male_approveddrugs_shared_mol_pval_dict = {}
male_approveddrugs_shared_mol_fdr_dict = {}
male_approveddrugs_shared_mol_sigfdr_dict = {}

for disA,druglist in male_trajectories_dict_filtered_unique_with_drugs_dict_explicit.items():
    try:
        drug_overlap_pval = float(fisher_test(set(druglist),set(male_trajectories_dict_filtered_unique_mol_sig_drug_dict[disA]),len(tot_drug_list)))
        male_approveddrugs_shared_mol_pval_dict[disA]=drug_overlap_pval
    except:
        pass
    
drug_intersection_adj_pval_list = fdr_adjustment(list(male_approveddrugs_shared_mol_pval_dict.values()),0.05)
pair_list=list(male_approveddrugs_shared_mol_pval_dict.keys())
for i in range(len(drug_intersection_adj_pval_list)):
    male_approveddrugs_shared_mol_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

for dis_pair,fdr in male_approveddrugs_shared_mol_fdr_dict.items():
    if fdr<0.05:
        male_approveddrugs_shared_mol_sigfdr_dict[dis_pair] = fdr


print(len(male_approveddrugs_shared_mol_sigfdr_dict))
# Out:
# 0

# %%
#Let's check that the amount of diseases that have approved/indicated drugs also from a molecular point of view

female_approveddrugs_shared_mol_pval_dict = {}
female_approveddrugs_shared_mol_fdr_dict = {}
female_approveddrugs_shared_mol_sigfdr_dict = {}

for disA,druglist in female_trajectories_dict_filtered_unique_with_drugs_dict_explicit.items():
    try:
        drug_overlap_pval = float(fisher_test(set(druglist),set(female_trajectories_dict_filtered_unique_mol_sig_drug_dict[disA]),len(tot_drug_list)))
        female_approveddrugs_shared_mol_pval_dict[disA]=drug_overlap_pval
    except:
        pass
    
drug_intersection_adj_pval_list = fdr_adjustment(list(female_approveddrugs_shared_mol_pval_dict.values()),0.05)
pair_list=list(female_approveddrugs_shared_mol_pval_dict.keys())
for i in range(len(drug_intersection_adj_pval_list)):
    female_approveddrugs_shared_mol_fdr_dict[pair_list[i]]=drug_intersection_adj_pval_list[i]

for dis_pair,fdr in female_approveddrugs_shared_mol_fdr_dict.items():
    if fdr<0.05:
        female_approveddrugs_shared_mol_sigfdr_dict[dis_pair] = fdr


print(len(female_approveddrugs_shared_mol_sigfdr_dict))
# Out:
# 4

# %%
female_approveddrugs_shared_mol_sigfdr_dict
# Out:
# {'71': np.float64(0.003408591591977155),
#  '73': np.float64(0.003408591591977155),
#  '428': np.float64(0.02786120295864357),
#  '441': np.float64(0.003408591591977155)}

# %%
female_trajectories_dict_filtered_unique_with_drugs_dict["71"]
# Out:
# {'D50', 'E03', 'E06'}

# %%
female_trajectories_dict_filtered_unique_with_drugs_dict["441"]
# Out:
# {'M19', 'M77'}

# %%
female_trajectories_dict_filtered_unique_with_drugs_dict_explicit["71"] & set(female_trajectories_dict_filtered_unique_mol_sig_drug_dict["71"])
# Out:
# {'Levothyroxine',
#  'Liotrix',
#  'Sodium ferric gluconate complex',
#  'Thyroid, porcine'}
