# %%
import pickle
import csv

in_file = "output/jaccard_pairs_from_n_plets_elma_list_fdr_dict_female.pickle"
out_file = in_file.replace(".pickle", ".csv")

with open(in_file, "rb") as f:
    data = pickle.load(f)

with open(out_file, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["key", "value"])
    for k, v in data.items():
        writer.writerow([k, v])

print(f"Wrote {out_file}")
# Out:
# Wrote output/jaccard_pairs_from_n_plets_elma_list_fdr_dict_female.csv
